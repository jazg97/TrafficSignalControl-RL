# %%
import numpy as np
import torch
import copy
import math
from torch.distributions import Categorical
from datetime import datetime
import gymnasium as gym
import os, shutil
import argparse

import torch.nn.functional as F
import torch.nn as nn
import torch.autograd as autograd 
import torch.optim as optim
from torch.nn.utils import clip_grad_norm_

import os
import datetime
from shutil import copyfile
import sys
import traci
import random
import timeit

from generator import TrafficGenerator
from memory import Memory     ## Prority Experience Memory 
from visualization import Visualization

from utils import import_train_configuration,set_sumo, set_train_path,get_model_path

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Actions

# %%
# phase codes based on SUMO environment.net.xml 
PHASE_NS_GREEN = 0  # action 0 for Variable Order
PHASE_NS_YELLOW = 1
PHASE_NSL_GREEN = 2  # action 1 for Variable Order
PHASE_NSL_YELLOW = 3
PHASE_EW_GREEN = 4  # action 2 for Variable Order
PHASE_EW_YELLOW = 5
PHASE_EWL_GREEN = 6  # action 3 for Variable Order
PHASE_EWL_YELLOW = 7

# New phases added
PHASE_N_SL_GREEN = 8
PHASE_N_SL_YELLOW= 9
PHASE_E_SL_GREEN = 10
PHASE_E_SL_YELLOW= 11
PHASE_S_SL_GREEN = 12
PHASE_S_SL_YELLOW= 13
PHASE_W_SL_GREEN = 14
PHASE_W_SL_YELLOW= 15

# %% [raw]
# #Duration_NS = 12
# #Duration_NSL = 9
# #Duration_EW = 16
# #Duration_EWL = 7
#
# Duration_NS = 18
# Duration_NSL = 7
# Duration_EW = 16
# Duration_EWL = 7
#
# Duration_N_SL = 10
# Duration_E_SL = 10
# Duration_S_SL = 10
# Duration_W_SL = 10
#
# # Duration_NS = 30
# # Duration_NSL = 11
# # Duration_EW = 22
# # Duration_EWL = 12
#
# O = [Duration_NS,Duration_NSL,Duration_EW,Duration_EWL]
# duration = [Duration_NS,Duration_NSL,Duration_EW,Duration_EWL]
# old_duration = [Duration_NS,Duration_NSL,Duration_EW,Duration_EWL]

# %% [markdown]
# # State

# %%
def _get_state():
    """
    Retrieve the state of the intersection from sumo, in the form of cell occupancy
    """
    state = np.zeros((3, 209, 206))   ## kind of like an RGB image
    lane = ["N2TL_0","N2TL_1","N2TL_2","E2TL_0","E2TL_1","E2TL_2","E2TL_3","S2TL_0","S2TL_1","S2TL_2","W2TL_0","W2TL_1","W2TL_2","W2TL_3"]
    # N, E, S, W
    #           N
    #   W               E
    #           S    
    car_list = traci.vehicle.getIDList()

    for car_id in car_list:
        lane_pos = traci.vehicle.getLanePosition(car_id)
        car_speed = traci.vehicle.getSpeed(car_id)
        lane_id = traci.vehicle.getLaneID(car_id)
        #Only information from incoming lanes
        if 'N2TL' in lane_id:            
            x = 100 + int(lane_id[-1])
            y = int(lane_pos//7.5)
            state[0][y][x] = 1 #presence / volume
            state[1][y][x] = car_speed / 50.0 # normalized velocity
            state[2][y][x] = traci.vehicle.getAccumulatedWaitingTime(car_id)/60.0 #waitingTime
            
        if 'E2TL' in lane_id:
            x = 205 - int(lane_pos//7.5)
            y = 99 + 1 + int(lane_id[-1])
            state[0][y][x] = 1 #presence / volume
            state[1][y][x] = car_speed / 50.0 #normalized velocity
            state[2][y][x] = traci.vehicle.getAccumulatedWaitingTime(car_id)/60.0 #waitingTime

        if 'S2TL' in lane_id:
            x = 100 + 3 + int(lane_id[-1])
            y = 207 + 1 - int(lane_pos//7.5)
            state[0][y][x] = 1 #presence / volume
            state[1][y][x] = car_speed / 50.0 #normalized velocity
            state[2][y][x] = traci.vehicle.getAccumulatedWaitingTime(car_id)/60.0 #waitingTime

        if 'W2TL' in lane_id:
            x = int(lane_pos//7.5)
            y = 99 + 1 + 4 + 3 - int(lane_id[-1])
            state[0][y][x] = 1 #presence / volume
            state[1][y][x] = car_speed /50.0 #normalized velocity
            state[2][y][x] = traci.vehicle.getAccumulatedWaitingTime(car_id)/60.0 #waitingTime

    #Return a partial view of the state
    return state[:, state.shape[1]//2 - 24: state.shape[1]//2 + 24, state.shape[2]//2 - 23: state.shape[2]//2 + 23]

# %% [markdown]
# # Environment

# %%
class Simulation:
    def __init__(self, Agent, TrafficGen, sumo_cmd, max_steps, green_duration, yellow_duration, num_states, num_actions, mode, device):
        self._Agent = Agent
        self._Actor = Agent.actor
        self._Critic= Agent.critic
        self._TrafficGen = TrafficGen
        self._step = 0
        self._sumo_cmd = sumo_cmd
        self._max_steps = max_steps 
        self._green_duration = green_duration
        self._yellow_duration = yellow_duration
        self._num_states = num_states
        self._num_actions = num_actions
        self._reward_store = []
        self._speed_store = []
        self._cumulative_wait_store = []
        self._avg_queue_length_store = []
        self._eval = mode
        self.dvc = device

    def run(self, episode, distribution='Weibull'):
        """
        Runs an episode of simulation, then starts a training session
        """
        self.training = False
        start_time = timeit.default_timer()

        # first, generate the route file for this simulation and set up sumo
        if not self._eval:
            self._TrafficGen.generate_routefile(seed=episode, distribution=distribution)
        else:
            self._TrafficGen.generate_routefile(seed=2000+episode, distribution=distribution)
        traci.start(self._sumo_cmd)
        print("Simulating...")

        # inits
        self._step = 0
        self._waiting_times = {}
        self._sum_neg_reward = 0
        self._sum_queue_length = 0
        self._sum_waiting_time = 0
        duration = [0,0,0,0,0,0,0,0]
        self._sum_speed = 0
        reward = 0
        re = 0
        current_phase = 0
        self.reward = 0
        done = 0
        old_action = 0
        last_queue = 0
        self._simulate(50)  ## Warm Environment
        h_out = (torch.zeros([1, 1, 128], dtype=torch.float).to(self.dvc), torch.zeros([1, 1, 128], dtype=torch.float).to(self.dvc))

        while self._step < self._max_steps:
            
            # get current state of the intersection
            current_state = _get_state()

            # calculate reward of previous action: 
            # waiting time = seconds waited by a car since the spawn in the environment, cumulated for every car in incoming lanes
            current_total_wait = self._collect_waiting_times()    

            #self._sum_waiting_time += current_total_wait
            # Types of reward
            # Waiting times
            # Queues
            # Avg speed            
            ## Your Reward Function
            ### Positive reward ---> when the queue length is reduced by the previously chosen action ----> delta < 0 ---> previous - curr > 0
            ### Negative reward ---> when the queue length is increased by the previously chosen action ----> delta > 0 ---> previous - curr < 0
            
            # Current light phase
            current_phase = int(traci.trafficlight.getPhase("TL")/2)
            # Chosen action
            h_in = h_out
            action, logprob_a, h_out = self._choose_action(current_state, h_in, self._eval)            
            last_queue = self._get_queue_length()

            # saving the data into the memory                
            # if the chosen phase is different from the last phase, activate the yellow phase
            if self._step != 0 and old_action != action:# and i == 0:
                self._set_yellow_phase(current_phase)
                self._simulate(self._yellow_duration)
                duration[action] = self._green_duration
                #last_queue = self._get_queue_length()
                # Perform chosen action on environment
                self._set_green_phase(action)
                self._simulate(self._green_duration)    
            elif self._step != 0 and old_action == action:
                #last_queue = self._get_queue_length()
                # Perform chosen action on environment
                self._set_green_phase(action)
                self._simulate(7)
            # Capture next state information
            reward = -self._get_queue_length() #+ last_queue
            if self._step != 0:
                next_state = _get_state()
                if self._step < self._max_steps - self._green_duration - self._yellow_duration:
                    done = 0
                else:
                    done = 1
                if not self._eval and agent.idx < agent.T_horizon:
                    cat_hin = torch.cat((h_in[0], h_in[1]), dim=1).cpu()
                    cat_hout = torch.cat((h_out[0], h_out[1]), dim=1).cpu()
                    self._Agent.put_data(current_state, action, reward, next_state, logprob_a, cat_hin.numpy(), cat_hout.numpy(), done, done)            
            # saving only the meaningful reward to better see if the agent is behaving correctly
            #if reward < 0:
            self._sum_neg_reward += reward
            re += 1
            old_action = action
        
        self.reward = self._sum_neg_reward/re
                
        print("Total Queue:",self._sum_queue_length, "  ", "Average Reward:", self.reward)
        print("Average Waiting time: {:.4f}".format(self._sum_waiting_time/1000))
        print("Average Speed: {:.4f}".format(self._sum_speed/self._max_steps))
        print("Average Queue length: {:.4f}".format(self._sum_queue_length / self._max_steps))
        
        self._save_episode_stats()
        traci.close()
        simulation_time = round(timeit.default_timer() - start_time, 1)
        if not self._eval: 
            return simulation_time
        else:
            return simulation_time, self.reward

    def _simulate(self, steps_todo):
        """
        Execute steps in sumo while gathering statistics
        """
        if (self._step + steps_todo) >= self._max_steps:  # do not do more steps than the maximum allowed number of steps
            steps_todo = self._max_steps - self._step

        while steps_todo > 0:
            traci.simulationStep()  # simulate 1 step in sumo
            self._step += 1 # update the step counter
            steps_todo -= 1
            queue_length = self._get_queue_length()
            self._sum_queue_length += queue_length
            self._sum_waiting_time += queue_length # 1 step while wating in queue means 1 second waited, for each car, therefore queue_lenght == waited_seconds
            speed = self._get_speed()
            self._sum_speed += speed
        
    def _collect_waiting_times(self):            # For reward 
        """
        Retrieve the waiting time of every car in the incoming roads
        """
        incoming_roads = ["E2TL", "N2TL", "W2TL", "S2TL"]
        car_list = traci.vehicle.getIDList()
        self._waiting_times = {}
        for car_id in car_list:
            wait_time = traci.vehicle.getAccumulatedWaitingTime(car_id)
            road_id = traci.vehicle.getRoadID(car_id)  # get the road id where the car is located
            if road_id in incoming_roads:  # consider only the waiting times of cars in incoming roads
                self._waiting_times[car_id] = wait_time 
            else:
                if car_id in self._waiting_times: # a car that was tracked has cleared the intersection
                    del self._waiting_times[car_id] 
                
        if len(self._waiting_times) == 0: 
            total_waiting_time = 0
        else: 
            total_waiting_time = sum(self._waiting_times.values())/len(self._waiting_times)
        return total_waiting_time 

    def _choose_action(self, state, h_in, deterministic):
        state = torch.from_numpy(state).float().to(self.dvc)
        #print(state.shape)
        with torch.no_grad():
            pi, h_out = self._Actor.pi(state, h_in, softmax_dim=-1)
            pi = pi.view(-1, 8) #Adjusting dimensions after LSTM layer
            if deterministic:
                action = torch.argmax(pi).item()
                return action, h_out, None
            else:
                m = Categorical(pi)
                action = m.sample()
                action_logprob = m.log_prob(action)
                return action.item(), action_logprob.item(), h_out

    def _set_yellow_phase(self, old_action):
        """
        Activate the correct yellow light combination in sumo
        """
        yellow_phase_code = old_action * 2 + 1 # obtain the yellow phase code, based on the old action (ref on environment.net.xml)
        traci.trafficlight.setPhase("TL", yellow_phase_code)

    def _set_green_phase(self, action_number):   ## For Variable Order Method 
        """
        Activate the correct green light combination in sumo
        """
        if action_number == 0:
            traci.trafficlight.setPhase("TL", PHASE_NS_GREEN)
        elif action_number == 1:
            traci.trafficlight.setPhase("TL", PHASE_NSL_GREEN)
        elif action_number == 2:
            traci.trafficlight.setPhase("TL", PHASE_EW_GREEN)
        elif action_number == 3:
            traci.trafficlight.setPhase("TL", PHASE_EWL_GREEN)
        elif action_number == 4:
            traci.trafficlight.setPhase('TL', PHASE_N_SL_GREEN)
        elif action_number == 5:
            traci.trafficlight.setPhase('TL', PHASE_E_SL_GREEN)
        elif action_number == 6:
            traci.trafficlight.setPhase('TL', PHASE_S_SL_GREEN)
        elif action_number == 7:
            traci.trafficlight.setPhase('TL', PHASE_W_SL_GREEN)

        # Add New phases (North Straight and Left, South Straight and Left, West Straight and Left, East Straight and Left)

    def _get_green(self,current_phase):       ## For Finetuning Method 
        if current_phase == 0:
            green = Duration_NS
        elif current_phase == 1:
            green = Duration_NSL
        elif current_phase == 2:
            green = Duration_EW
        elif current_phase == 3: 
            green = Duration_EWL
        else:
            green = Duration_N_SL
        
        return green

    def _get_queue_length(self):          # For evaluation 
        """
        Retrieve the number of cars with speed = 0 in every incoming lane
        """
        halt_N = traci.edge.getLastStepHaltingNumber("N2TL")
        halt_S = traci.edge.getLastStepHaltingNumber("S2TL")
        halt_E = traci.edge.getLastStepHaltingNumber("E2TL")
        halt_W = traci.edge.getLastStepHaltingNumber("W2TL")
        queue_length = halt_N + halt_S + halt_E + halt_W
        return queue_length
    
    def _get_speed(self):                  # For evaluation 
        total_speed = 0
        car_list = traci.vehicle.getIDList()
        for car_id in car_list:
            car_speed = traci.vehicle.getSpeed(car_id)
            total_speed +=car_speed
        if len(car_list) == 0: 
            s = 0
        else: 
            s = total_speed/len(car_list)
        return s
            
    def _save_episode_stats(self):
        """
        Save the stats of the episode to plot the graphs at the end of the session
        """
        self._reward_store.append(self.reward)  # how much negative reward in this episode
        self._speed_store.append(self._sum_speed / self._max_steps)
        self._cumulative_wait_store.append(self._sum_waiting_time)  # total number of seconds waited by cars in this episode
        self._avg_queue_length_store.append(self._sum_queue_length / self._max_steps)  # average number of queued cars per step, in this episode
    
    @property
    def reward_store(self):
        return self._reward_store

    @property
    def speed_store(self):
        return self._speed_store
    
    @property
    def cumulative_wait_store(self):
        return self._cumulative_wait_store

    @property
    def avg_queue_length_store(self):
        return self._avg_queue_length_store

# %% [markdown]
# # Actor-Critic Networks

# %%
def weight_init(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        nn.init.orthogonal_(m.weight)

class Actor(nn.Module):
    def __init__(self, action_dim):
        super(Actor, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, (5,5), (1,1), padding='same')
        self.pool1 = nn.MaxPool2d((2, 2), stride=2)
        self.conv2 = nn.Conv2d(16, 32, (3,3), (1,1), padding='same')
        self.pool2 = nn.MaxPool2d((2, 2), stride=2)
        self.lstm  = nn.LSTM(32*11*12, 128, 1, batch_first=True)
        self.l1 = nn.Linear(128, 64)
        self.l2 = nn.Linear(64, 32)
        self.l3 = nn.Linear(32, action_dim)        

    def forward(self, state, hidden):
        n = self.pool2(F.relu(self.conv2(self.pool1(F.relu(self.conv1(state))))))
        n = n.view(-1, 1, 32*11*12) #n.reshape(-1, 32*11*12)
        n, lstm_hidden = self.lstm(n, hidden) 
        n = torch.tanh(self.l1(n))
        n = torch.tanh(self.l2(n))
        return n, lstm_hidden

    def pi(self, state, hidden, softmax_dim = -1):
        n, lstm_hidden = self.forward(state, hidden)
        prob = F.softmax(self.l3(n), dim=softmax_dim)
        return prob, lstm_hidden

class Critic(nn.Module):
    def __init__(self):
        super(Critic, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, (5,5), (1,1), padding='same')
        self.pool1 = nn.MaxPool2d((2, 2), stride=2)
        self.conv2 = nn.Conv2d(16, 32, (3,3), (1,1), padding='same')
        self.pool2 = nn.MaxPool2d((2, 2), stride=2)
        self.lstm  = nn.LSTM(32*11*12, 128, 1, batch_first=True)
        self.C1 = nn.Linear(128, 64)
        self.C2 = nn.Linear(64, 32)
        self.C3 = nn.Linear(32, 1)

    def forward(self, state, hidden):
        v = self.pool2(F.relu(self.conv2(self.pool1(F.relu(self.conv1(state))))))
        v = v.view(-1, 1, 32*12*11)#reshape(-1, 32*12*11)
        v, lstm_hidden = self.lstm(v, hidden)
        v = torch.relu(self.C1(v))
        v = torch.relu(self.C2(v))
        v = self.C3(v)
        return v

# %% [markdown]
# # Policy Evaluation

# %%
import random
# Need to update to SUMO environment
def evaluate_policy(env, agent, turns = 3):
    total_scores = 0
    total_time = 0
    for j in range(turns):
        episode = random.randint(0, 2**31 - 1)
        simulation_time, reward = env.run(episode)
        total_scores += reward
        total_time += simulation_time
    return int(total_scores/turns), total_time

# %%
import scipy
# Function extracted from Hybrid-PPO SUMO implementation in https://github.com/Metro1998/hppo-in-traffic-signal-control/blob/main/src/hppo/HPPO.py
def discount_cumsum(x, discount):
    """
    magic from rllab for computing discounted cumulative sums of vectors.
    input:
        vector x,
        [x0,
         x1,
         x2]
    output:
        [x0 + discount * x1 + discount^2 * x2,
         x1 + discount * x2,
         x2]
    """
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]

# %% [markdown]
# # PPO Agent

# %%
# Need to update to SUMO environment
class PPO_agent():
    def __init__(self, **kwargs):
        # Init hyperparameters for PPO agent, just like "self.gamma = opt.gamma, self.lambd = opt.lambd, ..."
        self.__dict__.update(kwargs)

        '''Build Actor and Critic'''
        self.actor = Actor(self.action_dim).to(self.dvc)
        self.actor.apply(weight_init)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=self.lr)
        self.critic = Critic().to(self.dvc)
        self.critic.apply(weight_init)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=self.lr)

        '''Build Trajectory holder'''
        self.s_hoder = np.zeros(([self.T_horizon] + self.state_dim), dtype=np.float32) #observation
        self.a_hoder = np.zeros((self.T_horizon, 1), dtype=np.int64) #action
        self.r_hoder = np.zeros((self.T_horizon, 1), dtype=np.float32) #reward
        self.s_next_hoder = np.zeros(([self.T_horizon] + self.state_dim), dtype=np.float32) #
        self.val_hoder = np.zeros((self.T_horizon,1), dtype=np.float32) #expected value
        self.logprob_a_hoder = np.zeros((self.T_horizon, 1), dtype=np.float32) #logprob_action
        self.hin_hoder  = np.zeros((self.T_horizon,2, self.lstm_units), dtype=np.float32)
        self.hout_hoder = np.zeros((self.T_horizon,2, self.lstm_units), dtype=np.float32)
        self.done_hoder = np.zeros((self.T_horizon, 1), dtype=np.bool_)
        self.dw_hoder = np.zeros((self.T_horizon, 1), dtype=np.bool_)
        self.idx = 0

        '''Training history'''
        self.actor_losses = []
        self.critic_losses= []
        self.entropies = []

    def train(self):
        start_time = timeit.default_timer()
        self.entropy_coef *= self.entropy_coef_decay #exploring decay
        '''Prepare PyTorch data from Numpy data'''
        s = torch.from_numpy(self.s_hoder).to(self.dvc)
        a = torch.from_numpy(self.a_hoder).to(self.dvc)
        r = torch.from_numpy(self.r_hoder).to(self.dvc)
        s_next = torch.from_numpy(self.s_next_hoder).to(self.dvc)
        old_prob_a = torch.from_numpy(self.logprob_a_hoder).to(self.dvc)
        
        h1_in, h2_in = torch.from_numpy(self.hin_hoder[:, 0, :]), torch.from_numpy(self.hin_hoder[:, 1, :])
        first_hidden = (h1_in.unsqueeze(0).to(self.dvc), h2_in.unsqueeze(0).to(self.dvc))
        h1_out, h2_out= torch.from_numpy(self.hout_hoder[:, 0, :]), torch.from_numpy(self.hout_hoder[:, 1, :])
        second_hidden = (h1_out.unsqueeze(0).to(self.dvc), h2_out.unsqueeze(0).to(self.dvc))
        
        done = torch.from_numpy(self.done_hoder).to(self.dvc)
        dw = torch.from_numpy(self.dw_hoder).to(self.dvc)

        ''' Use TD+GAE+LongTrajectory to compute Advantage and TD target'''
        with torch.no_grad():
            vs = self.critic(s, first_hidden).squeeze(1)
            vs_ = self.critic(s_next, second_hidden).squeeze(1)

            '''GAE calculation'''
            deltas = r + self.gamma*vs_*(~dw) - vs #self.gamma * vs_ * (~dw)
            deltas = deltas.cpu().flatten().numpy()            
            
            adv = [0]

            '''done for GAE'''
            for dlt, done in zip(deltas[::-1], done.cpu().flatten().numpy()[::-1]):
                advantage = dlt + self.gamma * self.lambd * adv[-1] * (~done)
                adv.append(advantage)
            adv.reverse()
            #adv = discount_cumsum(deltas, self.gamma * self.lambd)            
            adv = copy.deepcopy(adv[:-1])
            adv = torch.tensor(adv).unsqueeze(1).float().to(self.dvc)

            td_target = adv + vs
            if self.adv_normalization:
                adv = (adv - adv.mean()) / ((adv.std() + 1e-4))  #sometimes helps

        """PPO update"""
        #Slice long trajectopy into short trajectory and perform mini-batch PPO update
        optim_iter_num = int(math.ceil(s.shape[0] / self.batch_size))

        for _ in range(self.K_epochs):
            #Shuffle the trajectory, Good for training
            perm = np.arange(s.shape[0])
            np.random.shuffle(perm)
            perm = torch.LongTensor(perm).to(self.dvc)
            s, a, td_target, adv, old_prob_a, f1, f2 = \
                s[perm].clone(), a[perm].clone(), td_target[perm].clone(), adv[perm].clone(), old_prob_a[perm].clone(), first_hidden[0][:, perm, :].clone(), first_hidden[1][:, perm, :].clone()
            '''mini-batch PPO update'''
            for i in range(optim_iter_num):
                index = slice(i * self.batch_size, min((i + 1) * self.batch_size, s.shape[0]))

                self.actor_optimizer.zero_grad()                
                '''actor update'''
                prob, _ = self.actor.pi(s[index], (f1[:, index, :], f2[:, index, :]), softmax_dim=-1)
                prob = prob.view(-1,8)
                entropy = Categorical(prob).entropy().sum(0, keepdim=True)
                prob_a = prob.gather(1, a[index])
                ratio = torch.exp(torch.log(prob_a) - old_prob_a[index])  # a/b == exp(log(a)-log(b))

                surr1 = ratio * adv[index]
                surr2 = torch.clamp(ratio, 1 - self.clip_rate, 1 + self.clip_rate) * adv[index]
                a_loss = -torch.min(surr1, surr2) - self.entropy_coef * entropy.view(-1,1)

                a_loss.mean().backward()
                torch.nn.utils.clip_grad_norm_(self.actor.parameters(), norm_type=2, max_norm=40)
                self.actor_optimizer.step()

                self.critic_optimizer.zero_grad()
                '''critic update'''
                c_loss = (self.critic(s[index], (f1[:, index, :], f2[:, index, :])).view(-1,1) - td_target[index]).pow(2).mean()
                for name, param in self.critic.named_parameters():
                    if 'weight' in name:
                        c_loss += param.pow(2).sum() * self.l2_reg
                
                c_loss.backward()
                self.critic_optimizer.step()
        simulation_time = round(timeit.default_timer() - start_time, 1)
        return simulation_time, a_loss.mean(), c_loss, entropy.mean()

    def put_data(self, s, a, r, s_next, logprob_a, h_in, h_out, done, dw):
        self.s_hoder[self.idx] = s
        self.a_hoder[self.idx] = a
        self.r_hoder[self.idx] = r
        self.s_next_hoder[self.idx] = s_next
        self.logprob_a_hoder[self.idx] = logprob_a
        self.hin_hoder[self.idx] = h_in
        self.hout_hoder[self.idx]= h_out
        self.done_hoder[self.idx] = done
        self.dw_hoder[self.idx] = dw
        self.idx+=1

    def save(self, episode):
        torch.save(self.critic.state_dict(), "./models/ppo_critic{}.pth".format(episode))
        torch.save(self.actor.state_dict(), "./models/ppo_actor{}.pth".format(episode))

    def load(self, episode):
        self.critic.load_state_dict(torch.load("./models/ppo_critic{}.pth".format(episode)))
        self.actor.load_state_dict(torch.load("./models/ppo_actor{}.pth".format(episode)))

# %%
class PPOOptions:
    def __init__(self, dvc: str = 'cuda', EnvIndex: int = 0, render: bool = False, seed: int = 209, T_horizon: int = 2048,
                 Max_train_steps: int = 5e7, eval_interval: int = 5e3, gamma: float = 0.99, lambd: float = 0.95, clip_rate: float = 0.2,
                 K_epochs: int = 10, net_width: int = 64, lr: float = 1e-4, l2_reg: float = 0, batch_size: int = 64, entropy_coef: float = 0,
                 entropy_coef_decay: float = 0.99, adv_normalization: bool = False,  lstm_units: int = 128):

        self.dvc = dvc
        self.EnvIdex = EnvIndex
        self.render = render
        self.seed = seed
        self.T_horizon = T_horizon
        self.Max_train_steps = Max_train_steps
        self.eval_interval = eval_interval
        self.gamma = gamma
        self.lambd = lambd
        self.clip_rate = clip_rate
        self.K_epochs = K_epochs
        self.net_width = net_width
        self.lr = lr
        self.l2_reg = l2_reg
        self.batch_size = batch_size
        self.entropy_coef = entropy_coef
        self.entropy_coef_decay = entropy_coef_decay
        self.adv_normalization = adv_normalization
        self.lstm_units = lstm_units

# %%
model_to_test = 1   # load model
if __name__ == "__main__":
    config = import_train_configuration(config_file='training_settings.ini')
    sumo_cmd = set_sumo(False, config['sumocfg_file_name'], 3600)
    path = set_train_path(config['models_path_name'])
    model_path = get_model_path(config['models_path_name'], model_to_test)
    opt = PPOOptions(entropy_coef = 0.1, T_horizon = 256, eval_interval= 500, K_epochs=15, adv_normalization = True, batch_size=16, lr = 1e-5, l2_reg=0.1)
    opt.dvc = torch.device(opt.dvc) # from str to torch.device
    opt.state_dim = [3,48,46]
    opt.action_dim = 8
    opt.max_e_steps = 3600
    n_cars_generated = 1000
    green_duration = 7
    yellow_duration = 6
    total_episodes = 800

    agent = PPO_agent(**vars(opt)) #DRL_Model(num_layers, width_layers, batch_size, learning_rate, input_dim=num_states, output_dim=num_actions,tau=1,num_atoms=num_atoms)

    trafficGen = TrafficGenerator(opt.max_e_steps, n_cars_generated)

    visualization = Visualization(path, dpi=96)
        
    simulation = Simulation(agent,trafficGen,sumo_cmd,opt.max_e_steps,green_duration,yellow_duration,opt.state_dim,opt.action_dim, False, opt.dvc)

    evaluation = Simulation(agent,trafficGen,sumo_cmd,opt.max_e_steps,green_duration,yellow_duration,opt.state_dim,opt.action_dim, True, opt.dvc)
  
    episode = 0
    timestamp_start = datetime.datetime.now()
    introduction_pareto = 400
    dists = ['Weibull', 'Poisson']
    #break
    while episode < total_episodes:
        print('\n----- Episode', str(episode+1), 'of', str(total_episodes))
        print(agent.idx, agent.T_horizon)
        for dist in dists:
            simulation_time = simulation.run(episode, dist)  # run the simulation
            if (agent.idx) % opt.T_horizon == 0:
                training_time, actor_loss, critic_loss, entropy = agent.train()
                agent.critic_losses.append(critic_loss)
                agent.actor_losses.append(actor_loss)
                agent.entropies.append(entropy)
                agent.idx = 0
                print('Traffic Distribution: {}'.format(dist))
                print('Simulation time:', simulation_time, 's - Training time:', training_time, 's - Total:', round(simulation_time+training_time, 1), 's')
                print('Actor loss: {:.4f}, Critic loss: {:.4f}'.format(actor_loss, critic_loss))
                print('Entropy: {}'.format(entropy))
            else:
                print('Simulation time:', simulation_time, 's')
        '''Record & log'''
        if (episode+1) % opt.eval_interval == 0:
            score, eval_time = evaluate_policy(evaluation, agent, turns=3) # evaluate the policy for 3 times, and get averaged result
            print('Evaluation time:', eval_time, 's', 'Score:', score)
            #if opt.write: writer.add_scalar('ep_r', score, global_step=total_steps)
            #print('EnvName:',EnvName[0],'seed:',env_seed,'steps: {}k'.format(int(total_steps/1000)),'score:', score)        
        episode += 1
        if episode == introduction_pareto:
            dists.append("Pareto")

    print("\n----- Start time:", timestamp_start)
    print("----- End time:", datetime.datetime.now())
    #print("----- Session info saved at:", path)
    #Model.save_model(path)
    #copyfile(src='training_settings.ini', dst=os.path.join(path, 'training_settings.ini'))
# Out:
# ----- Episode 1 of 800
# 0 256
# Simulating...
# Total Queue: 82905    Average Reward: -23.09556313993174
# Average Waiting time: 82.9050
# Average Speed: 7.3107
# Average Queue length: 23.0292
# Traffic Distribution: Weibull
# Simulation time: 43.0 s - Training time: 3.1 s - Total: 46.1 s
# Actor loss: -3.1616, Critic loss: 347869.7188
# Entropy: 33.10871887207031
# Simulating...
# Total Queue: 66362    Average Reward: -18.493006993006993
# Average Waiting time: 66.3620
# Average Speed: 8.7281
# Average Queue length: 18.4339
# Traffic Distribution: Poisson
# Simulation time: 39.3 s - Training time: 2.7 s - Total: 42.0 s
# Actor loss: -3.2424, Critic loss: 208231.2969
# Entropy: 33.1693115234375
#
# ----- Episode 2 of 800
# 0 256
# Simulating...
# Total Queue: 112614    Average Reward: -31.494809688581316
# Average Waiting time: 112.6140
# Average Speed: 5.8931
# Average Queue length: 31.2817
# Traffic Distribution: Weibull
# Simulation time: 51.6 s - Training time: 2.8 s - Total: 54.4 s
# Actor loss: -3.1768, Critic loss: 600068.1250
# Entropy: 33.13512420654297
# Simulating...
# Total Queue: 49601    Average Reward: -14.215017064846416
# Average Waiting time: 49.6010
# Average Speed: 9.5366
# Average Queue length: 13.7781
# Traffic Distribution: Poisson
# Simulation time: 35.8 s - Training time: 2.6 s - Total: 38.4 s
# Actor loss: -3.0257, Critic loss: 172860.7656
# Entropy: 33.084503173828125
#
# ----- Episode 3 of 800
# 0 256
# Simulating...
# Total Queue: 100925    Average Reward: -27.935153583617748
# Average Waiting time: 100.9250
# Average Speed: 6.4526
# Average Queue length: 28.0347
# Traffic Distribution: Weibull
# Simulation time: 48.3 s - Training time: 2.6 s - Total: 50.9 s
# Actor loss: -2.9902, Critic loss: 610854.8125
# Entropy: 33.122947692871094
# Simulating...
# Total Queue: 55356    Average Reward: -15.235294117647058
# Average Waiting time: 55.3560
# Average Speed: 9.4244
# Average Queue length: 15.3767
# Traffic Distribution: Poisson
# Simulation time: 36.2 s - Training time: 2.8 s - Total: 39.0 s
# Actor loss: -2.6851, Critic loss: 255388.6406
# Entropy: 33.161163330078125
#
# ----- Episode 4 of 800
# 0 256
# Simulating...
# Total Queue: 76868    Average Reward: -21.188356164383563
# Average Waiting time: 76.8680
# Average Speed: 7.2973
# Average Queue length: 21.3522
# Traffic Distribution: Weibull
# Simulation time: 43.1 s - Training time: 2.6 s - Total: 45.7 s
# Actor loss: -3.3667, Critic loss: 176465.9844
# Entropy: 33.20343017578125
# Simulating...
# Total Queue: 51929    Average Reward: -14.589473684210526
#
# ----- Episode 9 of 800
# 0 256
# Simulating...
# Total Queue: 98118    Average Reward: -27.831615120274915
# Average Waiting time: 98.1180
# Average Speed: 6.5521
# Average Queue length: 27.2550
# Traffic Distribution: Weibull
# Simulation time: 48.6 s - Training time: 2.8 s - Total: 51.4 s
# Actor loss: -2.7232, Critic loss: 580375.7500
# Entropy: 33.184608459472656
# Simulating...
# Total Queue: 54390    Average Reward: -15.550173010380623
# Average Waiting time: 54.3900
# Average Speed: 8.8381
# Average Queue length: 15.1083
# Traffic Distribution: Poisson
# Simulation time: 37.3 s - Training time: 2.8 s - Total: 40.1 s
# Actor loss: -2.6822, Critic loss: 199212.3125
# Entropy: 33.208778381347656
#
# ----- Episode 10 of 800
# 0 256
# Simulating...
# Total Queue: 117701    Average Reward: -32.30419580419581
# Average Waiting time: 117.7010
# Average Speed: 5.5894
# Average Queue length: 32.6947
# Traffic Distribution: Weibull
# Simulation time: 54.1 s - Training time: 2.8 s - Total: 56.9 s
# Actor loss: -2.8609, Critic loss: 504298.0312
# Entropy: 33.19530487060547
# Simulating...
# Total Queue: 75356    Average Reward: -20.578767123287673
# Average Waiting time: 75.3560
# Average Speed: 8.4581
# Average Queue length: 20.9322
# Traffic Distribution: Poisson
# Simulation time: 41.9 s - Training time: 2.7 s - Total: 44.6 s
# Actor loss: -2.7596, Critic loss: 266423.0312
# Entropy: 33.184715270996094
#
# ----- Episode 11 of 800
# 0 256
# Simulating...
# Total Queue: 85566    Average Reward: -23.455172413793104
# Average Waiting time: 85.5660
# Average Speed: 7.1397
# Average Queue length: 23.7683
# Traffic Distribution: Weibull
# Simulation time: 44.8 s - Training time: 2.8 s - Total: 47.6 s
# Actor loss: -2.5337, Critic loss: 396874.6562
# Entropy: 33.124046325683594
# Simulating...
# Total Queue: 64793    Average Reward: -17.92808219178082
# Average Waiting time: 64.7930
# Average Speed: 9.0517
# Average Queue length: 17.9981
# Traffic Distribution: Poisson
# Simulation time: 39.4 s - Training time: 2.7 s - Total: 42.1 s
# Actor loss: -2.4652, Critic loss: 272694.8750
# Entropy: 33.08008575439453
#
# ----- Episode 12 of 800
# 0 256
# Simulating...
# Total Queue: 72417    Average Reward: -20.209059233449477
# Average Waiting time: 72.4170
# Average Speed: 6.4776
# Average Queue length: 20.1158
# Traffic Distribution: Weibull
# Simulation time: 41.3 s - Training time: 2.7 s - Total: 44.0 s
# Actor loss: -2.9932, Critic loss: 150580.9062
# Entropy: 33.158180236816406
# Simulating...
# Total Queue: 58855    Average Reward: -16.155709342560552
# Average Waiting time: 58.8550
# Average Speed: 9.4853
# Average Queue length: 16.3486
# Traffic Distribution: Poisson
# Simulation time: 36.8 s - Training time: 2.7 s - Total: 39.5 s
# Actor loss: -2.9897, Critic loss: 98621.0547
# Entropy: 33.14570999145508
#
# ----- Episode 13 of 800
# 0 256
# Simulating...
# Total Queue: 69288    Average Reward: -19.171821305841924
# Average Waiting time: 69.2880
# Average Speed: 8.0749
# Average Queue length: 19.2467
# Traffic Distribution: Weibull
# Simulation time: 40.8 s - Training time: 2.8 s - Total: 43.6 s
# Actor loss: -2.8316, Critic loss: 134627.6875
# Entropy: 33.11705017089844
# Simulating...
# Total Queue: 48833    Average Reward: -13.590909090909092
# Average Waiting time: 48.8330
# Average Speed: 9.3872
# Average Queue length: 13.5647
# Traffic Distribution: Poisson
# Simulation time: 35.6 s - Training time: 2.8 s - Total: 38.4 s
# Actor loss: -2.4760, Critic loss: 112282.8750
# Entropy: 33.19481658935547
#
# ----- Episode 14 of 800
# 0 256
# Simulating...
# Total Queue: 65810    Average Reward: -18.493055555555557
# Average Waiting time: 65.8100
# Average Speed: 8.5305
# Average Queue length: 18.2806
# Traffic Distribution: Weibull
# Simulation time: 41.2 s - Training time: 2.6 s - Total: 43.8 s
# Actor loss: -2.7239, Critic loss: 161695.7812
# Entropy: 33.16410827636719
# Simulating...
# Total Queue: 53527    Average Reward: -15.157534246575343
# Average Waiting time: 53.5270
# Average Speed: 9.1529
# Average Queue length: 14.8686
# Traffic Distribution: Poisson
# Simulation time: 36.3 s - Training time: 2.6 s - Total: 38.9 s
# Actor loss: -2.4075, Critic loss: 157637.6719
# Entropy: 33.170799255371094
#
# ----- Episode 15 of 800
# 0 256
# Simulating...
# Total Queue: 71903    Average Reward: -20.027874564459932
# Average Waiting time: 71.9030
# Average Speed: 8.3778
# Average Queue length: 19.9731
# Traffic Distribution: Weibull
# Simulation time: 41.8 s - Training time: 2.8 s - Total: 44.6 s
# Actor loss: -2.3384, Critic loss: 315021.0000
# Entropy: 33.13113021850586
# Simulating...
# Total Queue: 85981    Average Reward: -23.783505154639176
# Average Waiting time: 85.9810
# Average Speed: 8.1642
# Average Queue length: 23.8836
# Traffic Distribution: Poisson
# Simulation time: 44.6 s - Training time: 2.7 s - Total: 47.3 s
# Actor loss: -2.7938, Critic loss: 249269.8906
# Entropy: 33.16282272338867
#
# ----- Episode 16 of 800
# 0 256
# Simulating...
# Total Queue: 108907    Average Reward: -31.219931271477662
# Average Waiting time: 108.9070
# Average Speed: 5.9926
# Average Queue length: 30.2519
# Traffic Distribution: Weibull
# Simulation time: 50.8 s - Training time: 2.6 s - Total: 53.4 s
# Actor loss: -2.1965, Critic loss: 675265.4375
# Entropy: 33.09519958496094
# Simulating...
# Total Queue: 55925    Average Reward: -15.604166666666666
# Average Waiting time: 55.9250
# Average Speed: 9.0320
# Average Queue length: 15.5347
# Traffic Distribution: Poisson
# Simulation time: 37.1 s - Training time: 2.6 s - Total: 39.7 s
# Actor loss: -2.4441, Critic loss: 126590.0547
# Entropy: 33.184730529785156
#
# ----- Episode 17 of 800
# 0 256
# Simulating...
# Total Queue: 60885    Average Reward: -17.01023890784983
# Average Waiting time: 60.8850
# Average Speed: 8.6836
# Average Queue length: 16.9125
# Traffic Distribution: Weibull
# Simulation time: 38.8 s - Training time: 2.7 s - Total: 41.5 s
# Actor loss: -2.6997, Critic loss: 150019.8281
# Entropy: 33.17607879638672
# Simulating...
# Total Queue: 39778    Average Reward: -11.010452961672474
# Average Waiting time: 39.7780
# Average Speed: 9.6685
# Average Queue length: 11.0494
# Traffic Distribution: Poisson
# Simulation time: 32.5 s - Training time: 2.8 s - Total: 35.3 s
# Actor loss: -2.2280, Critic loss: 80461.2734
# Entropy: 33.14134979248047
#
# ----- Episode 18 of 800
# 0 256
# Simulating...
# Total Queue: 66048    Average Reward: -18.598615916955016
# Average Waiting time: 66.0480
# Average Speed: 8.2812
# Average Queue length: 18.3467
# Traffic Distribution: Weibull
# Simulation time: 40.4 s - Training time: 3.0 s - Total: 43.4 s
# Actor loss: -2.6451, Critic loss: 130630.9062
# Entropy: 33.14491271972656
# Simulating...
# Total Queue: 105109    Average Reward: -30.54794520547945
# Average Waiting time: 105.1090
# Average Speed: 8.0204
# Average Queue length: 29.1969
# Traffic Distribution: Poisson
# Simulation time: 49.7 s - Training time: 2.7 s - Total: 52.4 s
# Actor loss: -2.6256, Critic loss: 316995.3438
# Entropy: 33.131431579589844
#
# ----- Episode 19 of 800
# 0 256
# Simulating...
# Total Queue: 48477    Average Reward: -13.87062937062937
# Average Waiting time: 48.4770
# Average Speed: 8.8199
# Average Queue length: 13.4658
# Traffic Distribution: Weibull
# Simulation time: 36.2 s - Training time: 2.7 s - Total: 38.9 s
# Actor loss: -2.2855, Critic loss: 97645.2500
# Entropy: 33.15483093261719
# Simulating...
# Total Queue: 67231    Average Reward: -19.162068965517243
# Average Waiting time: 67.2310
# Average Speed: 9.1814
# Average Queue length: 18.6753
# Traffic Distribution: Poisson
# Simulation time: 39.3 s - Training time: 2.7 s - Total: 42.0 s
# Actor loss: -2.2920, Critic loss: 318750.4688
# Entropy: 33.10531997680664
#
# ----- Episode 20 of 800
# 0 256
# Simulating...
# Total Queue: 81012    Average Reward: -22.703071672354948
# Average Waiting time: 81.0120
# Average Speed: 6.7778
# Average Queue length: 22.5033
# Traffic Distribution: Weibull
# Simulation time: 44.9 s - Training time: 2.7 s - Total: 47.6 s
# Actor loss: -1.9424, Critic loss: 382248.7188
# Entropy: 33.1932373046875
# Simulating...
# Total Queue: 43878    Average Reward: -12.163194444444445
# Average Waiting time: 43.8780
# Average Speed: 9.5476
# Average Queue length: 12.1883
# Traffic Distribution: Poisson
# Simulation time: 34.0 s - Training time: 2.7 s - Total: 36.7 s
# Actor loss: -2.1009, Critic loss: 105250.4141
# Entropy: 33.10942077636719
#
# ----- Episode 21 of 800
# 0 256
# Simulating...
# Total Queue: 61033    Average Reward: -16.924657534246574
# Average Waiting time: 61.0330
# Average Speed: 8.7598
# Average Queue length: 16.9536
# Traffic Distribution: Weibull
# Simulation time: 38.9 s - Training time: 2.7 s - Total: 41.6 s
# Actor loss: -1.9818, Critic loss: 231373.2188
# Entropy: 33.083824157714844
# Simulating...
# Total Queue: 109761    Average Reward: -30.822299651567945
# Average Waiting time: 109.7610
# Average Speed: 7.0515
# Average Queue length: 30.4892
# Traffic Distribution: Poisson
# Simulation time: 50.6 s - Training time: 2.6 s - Total: 53.2 s
# Actor loss: -2.2938, Critic loss: 391677.8438
# Entropy: 33.085601806640625
#
# ----- Episode 22 of 800
# 0 256
# Simulating...
# Total Queue: 107516    Average Reward: -30.318644067796612
# Average Waiting time: 107.5160
# Average Speed: 6.1403
# Average Queue length: 29.8656
# Traffic Distribution: Weibull
# Simulation time: 50.5 s - Training time: 2.7 s - Total: 53.2 s
# Actor loss: -2.3675, Critic loss: 348169.0000
# Entropy: 33.06842803955078
# Simulating...
# Total Queue: 47751    Average Reward: -13.491289198606271
# Average Waiting time: 47.7510
# Average Speed: 9.6057
# Average Queue length: 13.2642
# Traffic Distribution: Poisson
# Simulation time: 35.9 s - Training time: 2.7 s - Total: 38.6 s
# Actor loss: -1.9188, Critic loss: 106202.2891
# Entropy: 33.09619903564453
#
# ----- Episode 23 of 800
# 0 256
# Simulating...
# Total Queue: 113621    Average Reward: -31.364583333333332
# Average Waiting time: 113.6210
# Average Speed: 5.9185
# Average Queue length: 31.5614
# Traffic Distribution: Weibull
# Simulation time: 55.2 s - Training time: 2.6 s - Total: 57.8 s
# Actor loss: -2.1588, Critic loss: 671491.8125
# Entropy: 33.03521728515625
# Simulating...
# Total Queue: 44003    Average Reward: -12.208333333333334
# Average Waiting time: 44.0030
# Average Speed: 9.0330
# Average Queue length: 12.2231
# Traffic Distribution: Poisson
# Simulation time: 33.5 s - Training time: 2.7 s - Total: 36.2 s
# Actor loss: -2.3968, Critic loss: 59521.3203
# Entropy: 33.149723052978516
#
# ----- Episode 24 of 800
# 0 256
# Simulating...
# Total Queue: 109086    Average Reward: -30.270833333333332
# Average Waiting time: 109.0860
# Average Speed: 6.7464
# Average Queue length: 30.3017
# Traffic Distribution: Weibull
# Simulation time: 50.8 s - Training time: 2.7 s - Total: 53.5 s
# Actor loss: -2.0911, Critic loss: 513477.3438
# Entropy: 33.122650146484375
# Simulating...
# Total Queue: 55522    Average Reward: -15.363013698630137
# Average Waiting time: 55.5220
# Average Speed: 9.2675
# Average Queue length: 15.4228
# Traffic Distribution: Poisson
# Simulation time: 37.1 s - Training time: 2.8 s - Total: 39.9 s
# Actor loss: -2.0080, Critic loss: 166450.3750
# Entropy: 33.1698112487793
#
# ----- Episode 25 of 800
# 0 256
# Simulating...
# Total Queue: 94149    Average Reward: -26.458620689655174
# Average Waiting time: 94.1490
# Average Speed: 7.7292
# Average Queue length: 26.1525
# Traffic Distribution: Weibull
# Simulation time: 48.0 s - Training time: 2.6 s - Total: 50.6 s
# Actor loss: -1.9074, Critic loss: 452632.4375
# Entropy: 33.11167907714844
# Simulating...
# Total Queue: 66276    Average Reward: -18.651724137931033
# Average Waiting time: 66.2760
# Average Speed: 9.0498
# Average Queue length: 18.4100
# Traffic Distribution: Poisson
# Simulation time: 40.6 s - Training time: 2.7 s - Total: 43.3 s
# Actor loss: -2.1663, Critic loss: 164193.4062
# Entropy: 33.095523834228516
#
# ----- Episode 26 of 800
# 0 256
# Simulating...
# Total Queue: 60070    Average Reward: -16.342560553633216
# Average Waiting time: 60.0700
# Average Speed: 8.4091
# Average Queue length: 16.6861
# Traffic Distribution: Weibull
# Simulation time: 37.5 s - Training time: 2.8 s - Total: 40.3 s
# Actor loss: -2.1531, Critic loss: 103722.4219
# Entropy: 33.15681838989258
# Simulating...
# Total Queue: 41162    Average Reward: -11.354166666666666
# Average Waiting time: 41.1620
# Average Speed: 9.6193
# Average Queue length: 11.4339
# Traffic Distribution: Poisson
# Simulation time: 32.8 s - Training time: 2.7 s - Total: 35.5 s
# Actor loss: -1.9033, Critic loss: 69107.6875
# Entropy: 32.99131774902344
#
# ----- Episode 27 of 800
# 0 256
# Simulating...
# Total Queue: 129946    Average Reward: -36.90311418685121
# Average Waiting time: 129.9460
# Average Speed: 5.4022
# Average Queue length: 36.0961
# Traffic Distribution: Weibull
# Simulation time: 59.7 s - Training time: 2.6 s - Total: 62.3 s
# Actor loss: -2.3244, Critic loss: 304204.9375
# Entropy: 33.146636962890625
# Simulating...
# Total Queue: 63754    Average Reward: -17.96271186440678
# Average Waiting time: 63.7540
# Average Speed: 8.8811
# Average Queue length: 17.7094
# Traffic Distribution: Poisson
# Simulation time: 41.7 s - Training time: 2.7 s - Total: 44.4 s
# Actor loss: -1.8892, Critic loss: 190489.7344
# Entropy: 33.070640563964844
#
# ----- Episode 28 of 800
# 0 256
# Simulating...
# Total Queue: 49146    Average Reward: -13.893835616438356
# Average Waiting time: 49.1460
# Average Speed: 8.7176
# Average Queue length: 13.6517
# Traffic Distribution: Weibull
# Simulation time: 36.6 s - Training time: 3.1 s - Total: 39.7 s
# Actor loss: -2.0877, Critic loss: 94728.3125
# Entropy: 32.92500305175781
# Simulating...
# Total Queue: 74134    Average Reward: -20.71232876712329
# Average Waiting time: 74.1340
# Average Speed: 7.3024
# Average Queue length: 20.5928
# Traffic Distribution: Poisson
# Simulation time: 42.6 s - Training time: 2.7 s - Total: 45.3 s
# Actor loss: -2.1526, Critic loss: 173418.5000
# Entropy: 33.156959533691406
#
# ----- Episode 29 of 800
# 0 256
# Simulating...
# Total Queue: 41488    Average Reward: -11.206293706293707
# Average Waiting time: 41.4880
# Average Speed: 8.2101
# Average Queue length: 11.5244
# Traffic Distribution: Weibull
# Simulation time: 33.5 s - Training time: 2.8 s - Total: 36.3 s
# Actor loss: -1.9905, Critic loss: 47907.4180
# Entropy: 33.19743347167969
# Simulating...
# Total Queue: 51518    Average Reward: -14.154882154882156
# Average Waiting time: 51.5180
# Average Speed: 9.4493
# Average Queue length: 14.3106
# Traffic Distribution: Poisson
# Simulation time: 36.5 s - Training time: 2.8 s - Total: 39.3 s
# Actor loss: -1.6927, Critic loss: 122383.4297
# Entropy: 33.145816802978516
#
# ----- Episode 30 of 800
# 0 256
# Simulating...
# Total Queue: 57790    Average Reward: -15.66551724137931
# Average Waiting time: 57.7900
# Average Speed: 8.4775
# Average Queue length: 16.0528
# Traffic Distribution: Weibull
# Simulation time: 38.2 s - Training time: 2.8 s - Total: 41.0 s
# Actor loss: -1.9510, Critic loss: 99124.4688
# Entropy: 33.143165588378906
# Simulating...
# Total Queue: 71843    Average Reward: -20.13888888888889
# Average Waiting time: 71.8430
# Average Speed: 7.9295
# Average Queue length: 19.9564
# Traffic Distribution: Poisson
# Simulation time: 42.0 s - Training time: 2.7 s - Total: 44.7 s
# Actor loss: -1.5762, Critic loss: 257670.8594
# Entropy: 33.134849548339844
#
# ----- Episode 31 of 800
# 0 256
# Simulating...
# Total Queue: 64199    Average Reward: -17.919298245614034
# Average Waiting time: 64.1990
# Average Speed: 7.3443
# Average Queue length: 17.8331
# Traffic Distribution: Weibull
# Simulation time: 39.4 s - Training time: 2.8 s - Total: 42.2 s
# Actor loss: -1.9271, Critic loss: 82554.0391
# Entropy: 33.175010681152344
# Simulating...
# Total Queue: 60793    Average Reward: -17.07266435986159
# Average Waiting time: 60.7930
# Average Speed: 8.6139
# Average Queue length: 16.8869
# Traffic Distribution: Poisson
# Simulation time: 38.8 s - Training time: 2.7 s - Total: 41.5 s
# Actor loss: -2.1725, Critic loss: 97435.6250
# Entropy: 33.12063980102539
#
# ----- Episode 32 of 800
# 0 256
# Simulating...
# Total Queue: 83007    Average Reward: -22.593220338983052
# Average Waiting time: 83.0070
# Average Speed: 7.1267
# Average Queue length: 23.0575
# Traffic Distribution: Weibull
# Simulation time: 43.1 s - Training time: 2.7 s - Total: 45.8 s
# Actor loss: -1.8906, Critic loss: 244761.1562
# Entropy: 32.96237564086914
# Simulating...
# Total Queue: 55943    Average Reward: -15.506802721088436
# Average Waiting time: 55.9430
# Average Speed: 9.1185
# Average Queue length: 15.5397
# Traffic Distribution: Poisson
# Simulation time: 36.8 s - Training time: 2.7 s - Total: 39.5 s
# Actor loss: -1.5664, Critic loss: 152759.3438
# Entropy: 33.118370056152344
#
# ----- Episode 33 of 800
# 0 256
# Simulating...
# Total Queue: 48391    Average Reward: -13.348275862068965
# Average Waiting time: 48.3910
# Average Speed: 8.8137
# Average Queue length: 13.4419
# Traffic Distribution: Weibull
# Simulation time: 35.9 s - Training time: 2.7 s - Total: 38.6 s
# Actor loss: -1.7064, Critic loss: 56467.4453
# Entropy: 32.983741760253906
# Simulating...
# Total Queue: 60325    Average Reward: -16.5472972972973
# Average Waiting time: 60.3250
# Average Speed: 9.3106
# Average Queue length: 16.7569
# Traffic Distribution: Poisson
# Simulation time: 37.8 s - Training time: 2.8 s - Total: 40.6 s
# Actor loss: -1.7084, Critic loss: 143541.6875
# Entropy: 33.000301361083984
#
# ----- Episode 34 of 800
# 0 256
# Simulating...
# Total Queue: 56284    Average Reward: -15.363013698630137
# Average Waiting time: 56.2840
# Average Speed: 7.8825
# Average Queue length: 15.6344
# Traffic Distribution: Weibull
# Simulation time: 38.6 s - Training time: 2.6 s - Total: 41.2 s
# Actor loss: -1.5339, Critic loss: 123508.5234
# Entropy: 33.071083068847656
# Simulating...
# Total Queue: 41642    Average Reward: -11.802047781569966
# Average Waiting time: 41.6420
# Average Speed: 9.7574
# Average Queue length: 11.5672
# Traffic Distribution: Poisson
# Simulation time: 33.9 s - Training time: 3.0 s - Total: 36.9 s
# Actor loss: -1.6898, Critic loss: 61071.3555
# Entropy: 33.12281799316406
#
# ----- Episode 35 of 800
# 0 256
# Simulating...
# Total Queue: 63302    Average Reward: -17.498269896193772
# Average Waiting time: 63.3020
# Average Speed: 7.7701
# Average Queue length: 17.5839
# Traffic Distribution: Weibull
# Simulation time: 41.5 s - Training time: 3.0 s - Total: 44.5 s
# Actor loss: -1.5366, Critic loss: 133007.3594
# Entropy: 32.980072021484375
# Simulating...
# Total Queue: 110448    Average Reward: -31.320689655172412
# Average Waiting time: 110.4480
# Average Speed: 7.2134
# Average Queue length: 30.6800
# Traffic Distribution: Poisson
# Simulation time: 53.4 s - Training time: 2.8 s - Total: 56.2 s
# Actor loss: -1.6792, Critic loss: 389089.8438
# Entropy: 32.918174743652344
#
# ----- Episode 36 of 800
# 0 256
# Simulating...
# Total Queue: 146999    Average Reward: -40.95945945945946
# Average Waiting time: 146.9990
# Average Speed: 4.4785
# Average Queue length: 40.8331
# Traffic Distribution: Weibull
# Simulation time: 61.3 s - Training time: 2.7 s - Total: 64.0 s
# Actor loss: -1.6365, Critic loss: 1065683.3750
# Entropy: 32.90565872192383
# Simulating...
# Total Queue: 65261    Average Reward: -18.416666666666668
# Average Waiting time: 65.2610
# Average Speed: 8.8342
# Average Queue length: 18.1281
# Traffic Distribution: Poisson
# Simulation time: 40.8 s - Training time: 2.9 s - Total: 43.7 s
# Actor loss: -1.3436, Critic loss: 131728.7344
# Entropy: 33.082061767578125
#
# ----- Episode 37 of 800
# 0 256
# Simulating...
# Total Queue: 98878    Average Reward: -28.03071672354949
# Average Waiting time: 98.8780
# Average Speed: 7.2800
# Average Queue length: 27.4661
# Traffic Distribution: Weibull
# Simulation time: 47.1 s - Training time: 2.9 s - Total: 50.0 s
# Actor loss: -1.4245, Critic loss: 407377.5312
# Entropy: 32.76417922973633
# Simulating...
# Total Queue: 63767    Average Reward: -18.013468013468014
# Average Waiting time: 63.7670
# Average Speed: 8.5823
# Average Queue length: 17.7131
# Traffic Distribution: Poisson
# Simulation time: 41.3 s - Training time: 2.9 s - Total: 44.2 s
# Actor loss: -1.9029, Critic loss: 75566.2891
# Entropy: 33.152076721191406
#
# ----- Episode 38 of 800
# 0 256
# Simulating...
# Total Queue: 115414    Average Reward: -31.56551724137931
# Average Waiting time: 115.4140
# Average Speed: 6.7715
# Average Queue length: 32.0594
# Traffic Distribution: Weibull
# Simulation time: 54.6 s - Training time: 2.7 s - Total: 57.3 s
# Actor loss: -1.4117, Critic loss: 638470.5000
# Entropy: 32.87255859375
# Simulating...
# Total Queue: 58966    Average Reward: -16.47945205479452
# Average Waiting time: 58.9660
# Average Speed: 9.1856
# Average Queue length: 16.3794
# Traffic Distribution: Poisson
# Simulation time: 38.0 s - Training time: 2.9 s - Total: 40.9 s
# Actor loss: -1.5363, Critic loss: 103078.5000
# Entropy: 32.9730339050293
#
# ----- Episode 39 of 800
# 0 256
# Simulating...
# Total Queue: 53298    Average Reward: -15.058219178082192
# Average Waiting time: 53.2980
# Average Speed: 8.6462
# Average Queue length: 14.8050
# Traffic Distribution: Weibull
# Simulation time: 38.7 s - Training time: 2.7 s - Total: 41.4 s
# Actor loss: -1.0932, Critic loss: 158037.7656
# Entropy: 33.096839904785156
# Simulating...
# Total Queue: 87228    Average Reward: -24.328813559322032
# Average Waiting time: 87.2280
# Average Speed: 8.2436
# Average Queue length: 24.2300
# Traffic Distribution: Poisson
# Simulation time: 48.1 s - Training time: 2.7 s - Total: 50.8 s
# Actor loss: -2.0029, Critic loss: 97082.7891
# Entropy: 33.11109161376953
#
# ----- Episode 40 of 800
# 0 256
# Simulating...
# Total Queue: 136353    Average Reward: -38.14041095890411
# Average Waiting time: 136.3530
# Average Speed: 5.1625
# Average Queue length: 37.8758
# Traffic Distribution: Weibull
# Simulation time: 64.4 s - Training time: 2.8 s - Total: 67.2 s
# Actor loss: -1.5598, Critic loss: 601103.8750
# Entropy: 32.99376678466797
# Simulating...
# Total Queue: 54575    Average Reward: -15.465986394557824
# Average Waiting time: 54.5750
# Average Speed: 8.8512
# Average Queue length: 15.1597
# Traffic Distribution: Poisson
# Simulation time: 38.4 s - Training time: 2.9 s - Total: 41.3 s
# Actor loss: -1.1032, Critic loss: 103640.0938
# Entropy: 33.1231689453125
#
# ----- Episode 41 of 800
# 0 256
# Simulating...
# Total Queue: 42758    Average Reward: -11.672354948805461
# Average Waiting time: 42.7580
# Average Speed: 8.5806
# Average Queue length: 11.8772
# Traffic Distribution: Weibull
# Simulation time: 37.1 s - Training time: 2.9 s - Total: 40.0 s
# Actor loss: -1.1301, Critic loss: 83226.9766
# Entropy: 33.041324615478516
# Simulating...
# Total Queue: 66368    Average Reward: -19.242320819112628
# Average Waiting time: 66.3680
# Average Speed: 8.9466
# Average Queue length: 18.4356
# Traffic Distribution: Poisson
# Simulation time: 42.8 s - Training time: 2.8 s - Total: 45.6 s
# Actor loss: -1.7860, Critic loss: 77250.0547
# Entropy: 33.095497131347656
#
# ----- Episode 42 of 800
# 0 256
# Simulating...
# Total Queue: 77633    Average Reward: -21.70344827586207
# Average Waiting time: 77.6330
# Average Speed: 7.1624
# Average Queue length: 21.5647
# Traffic Distribution: Weibull
# Simulation time: 43.2 s - Training time: 2.8 s - Total: 46.0 s
# Actor loss: -1.4922, Critic loss: 233650.3281
# Entropy: 32.9437370300293
# Simulating...
# Total Queue: 78856    Average Reward: -22.01048951048951
# Average Waiting time: 78.8560
# Average Speed: 7.1039
# Average Queue length: 21.9044
# Traffic Distribution: Poisson
# Simulation time: 44.4 s - Training time: 2.7 s - Total: 47.1 s
# Actor loss: -1.4056, Critic loss: 156935.4062
# Entropy: 33.006080627441406
#
# ----- Episode 43 of 800
# 0 256
# Simulating...
# Total Queue: 67825    Average Reward: -18.986301369863014
# Average Waiting time: 67.8250
# Average Speed: 6.8858
# Average Queue length: 18.8403
# Traffic Distribution: Weibull
# Simulation time: 41.5 s - Training time: 2.8 s - Total: 44.3 s
# Actor loss: -1.1611, Critic loss: 117423.6719
# Entropy: 33.01976776123047
# Simulating...
# Total Queue: 82912    Average Reward: -23.03767123287671
# Average Waiting time: 82.9120
# ----- Episode 48 of 800
# 0 256
# Simulating...
# Total Queue: 65462    Average Reward: -18.09278350515464
# Average Waiting time: 65.4620
# Average Speed: 7.5562
# Average Queue length: 18.1839
# Traffic Distribution: Weibull
# Simulation time: 41.7 s - Training time: 2.9 s - Total: 44.6 s
# Actor loss: -1.0442, Critic loss: 162533.0469
# Entropy: 32.92178726196289
# Simulating...
# Total Queue: 58187    Average Reward: -16.356401384083046
# Average Waiting time: 58.1870
# Average Speed: 9.0544
# Average Queue length: 16.1631
# Traffic Distribution: Poisson
# Simulation time: 38.1 s - Training time: 2.8 s - Total: 40.9 s
# Actor loss: -1.3994, Critic loss: 73733.7031
# Entropy: 33.070335388183594
#
# ----- Episode 49 of 800
# 0 256
# Simulating...
# Total Queue: 71582    Average Reward: -20.16551724137931
# Average Waiting time: 71.5820
# Average Speed: 7.8629
# Average Queue length: 19.8839
# Traffic Distribution: Weibull
# Simulation time: 44.4 s - Training time: 2.6 s - Total: 47.0 s
# Actor loss: -1.1604, Critic loss: 170020.0938
# Entropy: 32.66975021362305
# Simulating...
# Total Queue: 61647    Average Reward: -17.338983050847457
# Average Waiting time: 61.6470
# Average Speed: 8.4772
# Average Queue length: 17.1242
# Traffic Distribution: Poisson
# Simulation time: 41.7 s - Training time: 2.7 s - Total: 44.4 s
# Actor loss: -1.1949, Critic loss: 72711.7266
# Entropy: 33.05154800415039
#
# ----- Episode 50 of 800
# 0 256
# Simulating...
# Total Queue: 59326    Average Reward: -16.282828282828284
# Average Waiting time: 59.3260
# Average Speed: 7.8716
# Average Queue length: 16.4794
# Traffic Distribution: Weibull
# Simulation time: 39.5 s - Training time: 2.7 s - Total: 42.2 s
# Actor loss: -1.4078, Critic loss: 42560.6875
# Entropy: 33.07374572753906
# Simulating...
# Total Queue: 58288    Average Reward: -16.238754325259517
# Average Waiting time: 58.2880
# Average Speed: 8.9090
# Average Queue length: 16.1911
# Traffic Distribution: Poisson
# Simulation time: 38.2 s - Training time: 2.8 s - Total: 41.0 s
# Actor loss: -1.0377, Critic loss: 63868.2031
# Entropy: 32.973480224609375
#
# ----- Episode 51 of 800
# 0 256
# Simulating...
# Total Queue: 69416    Average Reward: -19.44557823129252
# Average Waiting time: 69.4160
# Average Speed: 7.0579
# Average Queue length: 19.2822
# Traffic Distribution: Weibull
# Simulation time: 42.1 s - Training time: 2.6 s - Total: 44.7 s
# Actor loss: -1.4858, Critic loss: 75691.9766
# Entropy: 33.182456970214844
# Simulating...
# Total Queue: 67601    Average Reward: -19.065068493150687
# Average Waiting time: 67.6010
# Average Speed: 8.3064
# Average Queue length: 18.7781
# Traffic Distribution: Poisson
# Simulation time: 39.6 s - Training time: 2.8 s - Total: 42.4 s
# Actor loss: -1.1428, Critic loss: 25459.8281
# Entropy: 33.03007507324219
#
# ----- Episode 52 of 800
# 0 256
# Simulating...
# Total Queue: 68816    Average Reward: -18.79584775086505
# Average Waiting time: 68.8160
# Average Speed: 7.2865
# Average Queue length: 19.1156
# Traffic Distribution: Weibull
# ----- Episode 61 of 800
# 0 256
# Simulating...
# Total Queue: 127695    Average Reward: -36.33561643835616
# Average Waiting time: 127.6950
# Average Speed: 4.5520
# Average Queue length: 35.4708
# Traffic Distribution: Weibull
# Simulation time: 58.1 s - Training time: 2.7 s - Total: 60.8 s
# Actor loss: -1.2622, Critic loss: 305342.8438
# Entropy: 32.929359436035156
# Simulating...
# Total Queue: 87091    Average Reward: -24.756849315068493
# Average Waiting time: 87.0910
# Average Speed: 8.1133
# Average Queue length: 24.1919
# Traffic Distribution: Poisson
# Simulation time: 45.1 s - Training time: 2.7 s - Total: 47.8 s
# Actor loss: -0.9969, Critic loss: 193926.2500
# Entropy: 32.86054992675781
#
# ----- Episode 62 of 800
# 0 256
# Simulating...
# Total Queue: 59903    Average Reward: -16.51360544217687
# Average Waiting time: 59.9030
# Average Speed: 7.5607
# Average Queue length: 16.6397
# Traffic Distribution: Weibull
# Simulation time: 38.9 s - Training time: 2.8 s - Total: 41.7 s
# Actor loss: -1.1838, Critic loss: 101995.2812
# Entropy: 32.877750396728516
# Simulating...
# Total Queue: 43655    Average Reward: -11.993150684931507
# Average Waiting time: 43.6550
# Average Speed: 10.0718
# Average Queue length: 12.1264
# Traffic Distribution: Poisson
# Simulation time: 34.3 s - Training time: 2.8 s - Total: 37.1 s
# Actor loss: -0.7970, Critic loss: 56100.9102
# Entropy: 32.80933380126953
#
# ----- Episode 63 of 800
# 0 256
# Simulating...
# Total Queue: 70082    Average Reward: -19.55944055944056
# Average Waiting time: 70.0820
# Average Speed: 7.9015
# Average Queue length: 19.4672
# Traffic Distribution: Weibull
# Simulation time: 43.2 s - Training time: 2.7 s - Total: 45.9 s
# Actor loss: -1.2751, Critic loss: 45466.5781
# Entropy: 32.928260803222656
# Simulating...
# Total Queue: 108864    Average Reward: -30.427083333333332
# Average Waiting time: 108.8640
# Average Speed: 7.2593
# Average Queue length: 30.2400
# Traffic Distribution: Poisson
# Simulation time: 52.4 s - Training time: 2.8 s - Total: 55.2 s
# Actor loss: -1.2924, Critic loss: 86371.5078
# Entropy: 32.736961364746094
#
# ----- Episode 64 of 800
# 0 256
# Simulating...
# Total Queue: 41686    Average Reward: -11.53061224489796
# Average Waiting time: 41.6860
# Average Speed: 8.9438
# Average Queue length: 11.5794
# Traffic Distribution: Weibull
# Simulation time: 34.8 s - Training time: 2.7 s - Total: 37.5 s
# Actor loss: -0.6100, Critic loss: 34204.9062
# Entropy: 32.94683837890625
# Simulating...
# Total Queue: 69319    Average Reward: -19.215753424657535
# Average Waiting time: 69.3190
# Average Speed: 7.9958
# Average Queue length: 19.2553
# Traffic Distribution: Poisson
# Simulation time: 40.6 s - Training time: 2.6 s - Total: 43.2 s
# Actor loss: -0.8874, Critic loss: 41954.8867
# Entropy: 32.75458526611328
#
# ----- Episode 65 of 800
# 0 256
# Simulating...
# Total Queue: 54020    Average Reward: -14.945017182130584
# Average Waiting time: 54.0200
# Average Speed: 8.2773
# Average Queue length: 15.0056
# Traffic Distribution: Weibull
# Simulation time: 38.2 s - Training time: 2.8 s - Total: 41.0 s
# Actor loss: -0.7763, Critic loss: 48402.9180
# Entropy: 32.969181060791016
# Simulating...
# Total Queue: 53434    Average Reward: -15.034843205574912
# Average Waiting time: 53.4340
# Average Speed: 9.1185
# Average Queue length: 14.8428
# Traffic Distribution: Poisson
# Simulation time: 36.2 s - Training time: 2.8 s - Total: 39.0 s
# Actor loss: -1.3128, Critic loss: 94860.8359
# Entropy: 33.02125549316406
#
# ----- Episode 66 of 800
# 0 256
# Simulating...
# Total Queue: 72787    Average Reward: -19.865319865319865
# Average Waiting time: 72.7870
# Average Speed: 7.1846
# Average Queue length: 20.2186
# Traffic Distribution: Weibull
# Simulation time: 42.5 s - Training time: 2.6 s - Total: 45.1 s
# Actor loss: -0.8770, Critic loss: 43471.1562
# Entropy: 33.0374755859375
# Simulating...
# Total Queue: 70137    Average Reward: -19.925925925925927
# Average Waiting time: 70.1370
# Average Speed: 8.4314
# Average Queue length: 19.4825
# Traffic Distribution: Poisson
# Simulation time: 42.5 s - Training time: 2.7 s - Total: 45.2 s
# Actor loss: -0.6396, Critic loss: 68181.9766
# Entropy: 33.120792388916016
#
# ----- Episode 67 of 800
# 0 256
# Simulating...
# Total Queue: 97248    Average Reward: -27.655172413793103
# Average Waiting time: 97.2480
# Average Speed: 6.4086
# Average Queue length: 27.0133
# Traffic Distribution: Weibull
# Simulation time: 49.4 s - Training time: 2.7 s - Total: 52.1 s
# Actor loss: -0.8822, Critic loss: 102938.8438
# Entropy: 32.88083267211914
# Simulating...
# Total Queue: 52241    Average Reward: -14.525773195876289
# Average Waiting time: 52.2410
# Average Speed: 9.5054
# Average Queue length: 14.5114
# Traffic Distribution: Poisson
# Simulation time: 35.9 s - Training time: 2.8 s - Total: 38.7 s
# Actor loss: -1.1046, Critic loss: 86307.8516
# Entropy: 32.95394515991211
#
# ----- Episode 68 of 800
# 0 256
# Simulating...
# Total Queue: 80173    Average Reward: -23.013986013986013
# Average Waiting time: 80.1730
# Average Speed: 7.2422
# Average Queue length: 22.2703
# Traffic Distribution: Weibull
# Simulation time: 43.8 s - Training time: 2.8 s - Total: 46.6 s
# Actor loss: -1.2852, Critic loss: 69904.3906
# Entropy: 32.919158935546875
# Simulating...
# Total Queue: 54583    Average Reward: -15.523972602739725
# Average Waiting time: 54.5830
# Average Speed: 9.2425
# Average Queue length: 15.1619
# Traffic Distribution: Poisson
# Simulation time: 38.2 s - Training time: 2.8 s - Total: 41.0 s
# Actor loss: -1.2240, Critic loss: 50287.5508
# Entropy: 32.83418273925781
#
# ----- Episode 69 of 800
# 0 256
# Simulating...
# Total Queue: 48233    Average Reward: -13.397923875432525
# Average Waiting time: 48.2330
# Average Speed: 8.7337
# Average Queue length: 13.3981
# Traffic Distribution: Weibull
# Simulation time: 37.2 s - Training time: 3.1 s - Total: 40.3 s
# Actor loss: -0.7431, Critic loss: 70654.1719
# Entropy: 32.97031784057617
# Simulating...
# Total Queue: 39317    Average Reward: -11.127586206896552
# Average Waiting time: 39.3170
# Average Speed: 9.9796
# Average Queue length: 10.9214
# Traffic Distribution: Poisson
# Simulation time: 36.1 s - Training time: 3.0 s - Total: 39.1 s
# Actor loss: -0.6360, Critic loss: 26968.6660
# Entropy: 32.90470886230469
#
# ----- Episode 70 of 800
# 0 256
# Simulating...
# Total Queue: 88050    Average Reward: -24.79725085910653
# Average Waiting time: 88.0500
# Average Speed: 6.1783
# Average Queue length: 24.4583
# Traffic Distribution: Weibull
# Simulation time: 50.4 s - Training time: 2.9 s - Total: 53.3 s
# Actor loss: -1.1398, Critic loss: 84150.4219
# Entropy: 32.89680480957031
# Simulating...
# Total Queue: 58028    Average Reward: -16.103806228373703
# Average Waiting time: 58.0280
# Average Speed: 9.3429
# Average Queue length: 16.1189
# Traffic Distribution: Poisson
# Simulation time: 40.8 s - Training time: 2.9 s - Total: 43.7 s
# Actor loss: -0.8695, Critic loss: 28442.0430
# Entropy: 32.904937744140625
#
# ----- Episode 71 of 800
# 0 256
# Simulating...
# Total Queue: 63662    Average Reward: -17.46917808219178
# Average Waiting time: 63.6620
# Average Speed: 7.1246
# Average Queue length: 17.6839
# Traffic Distribution: Weibull
# Simulation time: 44.9 s - Training time: 2.9 s - Total: 47.8 s
# Actor loss: -0.7297, Critic loss: 22353.6211
# Entropy: 32.962764739990234
# Simulating...
# Total Queue: 87542    Average Reward: -24.75347222222222
# Average Waiting time: 87.5420
# Average Speed: 7.0375
# Average Queue length: 24.3172
# Traffic Distribution: Poisson
# Simulation time: 49.8 s - Training time: 2.8 s - Total: 52.6 s
# Actor loss: -0.5915, Critic loss: 41170.2617
# Entropy: 32.79143524169922
#
# ----- Episode 72 of 800
# 0 256
# Simulating...
# Total Queue: 104493    Average Reward: -28.965156794425088
# Average Waiting time: 104.4930
# Average Speed: 6.9583
# Average Queue length: 29.0258
# Traffic Distribution: Weibull
# Simulation time: 51.6 s - Training time: 2.8 s - Total: 54.4 s
# Actor loss: -0.7688, Critic loss: 140088.5938
# Entropy: 32.349639892578125
# Simulating...
# ...
# Average Waiting time: 18.5380
# Average Speed: 10.6752
# Average Queue length: 5.1494
# Traffic Distribution: Poisson
# Simulation time: 30.2 s - Training time: 2.7 s - Total: 32.9 s
# Actor loss: -0.4109, Critic loss: 9215.8262
# Entropy: 20.059558868408203
#
# ----- Episode 378 of 800
# 0 256
# Simulating...
# Total Queue: 71621    Average Reward: -19.86513157894737
# Average Waiting time: 71.6210
# Average Speed: 6.4094
# Average Queue length: 19.8947
# Traffic Distribution: Weibull
# Simulation time: 45.3 s - Training time: 2.7 s - Total: 48.0 s
# Actor loss: -0.0302, Critic loss: 14830.7900
# Entropy: 25.851728439331055
# Simulating...
# Total Queue: 15754    Average Reward: -4.378839590443686
# Average Waiting time: 15.7540
# Average Speed: 10.9894
# Average Queue length: 4.3761
# Traffic Distribution: Poisson
# Simulation time: 29.7 s - Training time: 2.9 s - Total: 32.6 s
# Actor loss: -0.1722, Critic loss: 26056.3867
# Entropy: 23.467348098754883
#
# ----- Episode 379 of 800
# 0 256
# Simulating...
# Actor loss: -0.5423, Critic loss: 3933.5483
# Entropy: 21.45852279663086
# Simulating...
# Total Queue: 14998    Average Reward: -4.1655629139072845
# Average Waiting time: 14.9980
# Average Speed: 11.3092
# Average Queue length: 4.1661
# Traffic Distribution: Poisson
# Simulation time: 30.3 s - Training time: 2.8 s - Total: 33.1 s
# Actor loss: -0.9225, Critic loss: 6475.5283
# Entropy: 21.333450317382812
#
# ----- Episode 397 of 800
# 0 256
# Simulating...
# Total Queue: 16863    Average Reward: -4.694805194805195
# Average Waiting time: 16.8630
# Average Speed: 9.3279
# Average Queue length: 4.6842
# Traffic Distribution: Weibull
# Simulation time: 33.0 s - Training time: 3.0 s - Total: 36.0 s
# Actor loss: -0.1892, Critic loss: 6834.1870
# Entropy: 22.932981491088867
# Simulating...
# Total Queue: 16275    Average Reward: -4.568627450980392
# Average Waiting time: 16.2750
# Average Speed: 11.0060
# Average Queue length: 4.5208
# Traffic Distribution: Poisson
# Simulation time: 33.5 s - Training time: 3.0 s - Total: 36.5 s
# Actor loss: -0.4438, Critic loss: 8034.1494
# Entropy: 22.195354461669922
#
# ----- Episode 398 of 800
# 0 256
# Simulating...
# Total Queue: 32711    Average Reward: -8.882736156351791
# Average Waiting time: 32.7110
# Average Speed: 7.8986
# Average Queue length: 9.0864
# Traffic Distribution: Weibull
# Simulation time: 35.9 s - Training time: 2.9 s - Total: 38.8 s
# Actor loss: -0.2860, Critic loss: 9566.7656
# Entropy: 22.484291076660156
# Simulating...
# Total Queue: 13072    Average Reward: -3.7225806451612904
# Average Waiting time: 13.0720
# Average Speed: 11.1126
# Average Queue length: 3.6311
# Traffic Distribution: Poisson
# Simulation time: 32.1 s - Training time: 3.1 s - Total: 35.2 s
# Actor loss: -0.1576, Critic loss: 7754.1792
# Entropy: 21.94087791442871
#
# ----- Episode 399 of 800
# 0 256
# Simulating...
# Total Queue: 27233    Average Reward: -7.6875
# Average Waiting time: 27.2330
# Average Speed: 7.3375
# Average Queue length: 7.5647
# Traffic Distribution: Weibull
# Simulation time: 36.5 s - Training time: 3.0 s - Total: 39.5 s
# Actor loss: -0.2742, Critic loss: 9067.9111
# Entropy: 18.6319580078125
# Simulating...
# Total Queue: 12731    Average Reward: -3.615894039735099
# Average Waiting time: 12.7310
# Average Speed: 11.2987
# Average Queue length: 3.5364
# Traffic Distribution: Poisson
# Simulation time: 31.4 s - Training time: 3.2 s - Total: 34.6 s
# Actor loss: 0.2207, Critic loss: 5991.0635
# Entropy: 21.889915466308594
#
# ----- Episode 400 of 800
# 0 256
# Simulating...
# Total Queue: 14079    Average Reward: -3.951923076923077
# Average Waiting time: 14.0790
# Average Speed: 9.9500
# Average Queue length: 3.9108
# Traffic Distribution: Weibull
# Simulation time: 33.5 s - Training time: 2.9 s - Total: 36.4 s
# Actor loss: 0.0348, Critic loss: 12340.9414
# Entropy: 19.478641510009766
# Simulating...
# Total Queue: 13867    Average Reward: -3.808306709265176
# Average Waiting time: 13.8670
# Average Speed: 11.2456
# Average Queue length: 3.8519
# Traffic Distribution: Poisson
# Simulation time: 31.3 s - Training time: 2.8 s - Total: 34.1 s
# Actor loss: 0.2589, Critic loss: 4866.8867
# Entropy: 19.144031524658203
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 57
#      55     episode += 1
#      56     if episode == introduction_pareto:
# ---> 57         dists.append(pareto)
#      59 print("\n----- Start time:", timestamp_start)
#      60 print("----- End time:", datetime.datetime.now())
#
# NameError: name 'pareto' is not defined

# %%
dists = ['Weibull', 'Poisson', 'Pareto']
episode=401
while episode < total_episodes:
        print('\n----- Episode', str(episode+1), 'of', str(total_episodes))
        print(agent.idx, agent.T_horizon)
        for dist in dists:
            simulation_time = simulation.run(episode, dist)  # run the simulation
            if (agent.idx) % opt.T_horizon == 0:
                training_time, actor_loss, critic_loss, entropy = agent.train()
                agent.critic_losses.append(critic_loss)
                agent.actor_losses.append(actor_loss)
                agent.entropies.append(entropy)
                agent.idx = 0
                print('Traffic Distribution: {}'.format(dist))
                print('Simulation time:', simulation_time, 's - Training time:', training_time, 's - Total:', round(simulation_time+training_time, 1), 's')
                print('Actor loss: {:.4f}, Critic loss: {:.4f}'.format(actor_loss, critic_loss))
                print('Entropy: {}'.format(entropy))
            else:
                print('Simulation time:', simulation_time, 's')
        '''Record & log'''
        if (episode+1) % opt.eval_interval == 0:
            score, eval_time = evaluate_policy(evaluation, agent, turns=3) # evaluate the policy for 3 times, and get averaged result
            print('Evaluation time:', eval_time, 's', 'Score:', score)
            #if opt.write: writer.add_scalar('ep_r', score, global_step=total_steps)
            #print('EnvName:',EnvName[0],'seed:',env_seed,'steps: {}k'.format(int(total_steps/1000)),'score:', score)        
        episode += 1
# Out:
# ----- Episode 402 of 800
# 0 256
# Simulating...
# Total Queue: 18419    Average Reward: -5.162790697674419
# Average Waiting time: 18.4190
# Average Speed: 9.2632
# Average Queue length: 5.1164
# Traffic Distribution: Weibull
# Simulation time: 31.5 s - Training time: 2.9 s - Total: 34.4 s
# Actor loss: -0.3809, Critic loss: 5618.8931
# Entropy: 21.159042358398438
# Simulating...
# Total Queue: 25399    Average Reward: -6.895622895622895
# Average Waiting time: 25.3990
# Average Speed: 10.6493
# Average Queue length: 7.0553
# Traffic Distribution: Poisson
# Simulation time: 30.6 s - Training time: 2.9 s - Total: 33.5 s
# Actor loss: 0.0837, Critic loss: 4066.2305
# Entropy: 23.53215217590332
# Simulating...
# Total Queue: 268609    Average Reward: -75.2
# Average Waiting time: 268.6090
# Average Speed: 2.7144
# Average Queue length: 74.6136
# Traffic Distribution: Pareto
# Simulation time: 105.7 s - Training time: 2.7 s - Total: 108.4 s
# Actor loss: -0.2044, Critic loss: 467639.0938
# Entropy: 25.9732666015625
#
# ----- Episode 403 of 800
# 0 256
# Simulating...
# Total Queue: 17794    Average Reward: -5.019543973941368
# Average Waiting time: 17.7940
# Average Speed: 8.9771
# Average Queue length: 4.9428
# Traffic Distribution: Weibull
# Simulation time: 29.8 s - Training time: 2.8 s - Total: 32.6 s
# Actor loss: -0.0093, Critic loss: 86369.3438
# Entropy: 22.615983963012695
# Simulating...
# Actor loss: -0.2290, Critic loss: 59320.4531
# Entropy: 14.791495323181152
# Simulating...
# Total Queue: 18779    Average Reward: -5.2063492063492065
# Average Waiting time: 18.7790
# Average Speed: 10.2503
# Average Queue length: 5.2164
# Traffic Distribution: Poisson
# Simulation time: 30.8 s - Training time: 3.2 s - Total: 34.0 s
# Actor loss: 0.0758, Critic loss: 25815.4707
# Entropy: 17.35222625732422
# Simulating...
# Total Queue: 296679    Average Reward: -80.6258064516129
# Average Waiting time: 296.6790
# Average Speed: 2.0067
# Average Queue length: 82.4108
# Traffic Distribution: Pareto
# Simulation time: 112.5 s - Training time: 2.8 s - Total: 115.3 s
# Actor loss: -0.3463, Critic loss: 440744.3125
# Entropy: 19.64764404296875
#
# ----- Episode 410 of 800
# 0 256
# Simulating...
# Total Queue: 14178    Average Reward: -3.8365384615384617
# Average Waiting time: 14.1780
# Average Speed: 10.4356
# Average Queue length: 3.9383
# Traffic Distribution: Weibull
# Simulation time: 28.7 s - Training time: 2.7 s - Total: 31.4 s
# Actor loss: -0.4777, Critic loss: 68037.2188
# Entropy: 18.364925384521484
# Simulating...
# Total Queue: 14754    Average Reward: -4.198675496688741
# Average Waiting time: 14.7540
# Average Speed: 10.8114
# Average Queue length: 4.0983
# Traffic Distribution: Poisson
# Simulation time: 30.5 s - Training time: 2.9 s - Total: 33.4 s
# Actor loss: 0.2467, Critic loss: 41099.1680
# Entropy: 21.228107452392578
# Simulating...
# Total Queue: 258162    Average Reward: -73.15686274509804
# Average Waiting time: 258.1620
# Average Speed: 3.2052
# Average Queue length: 71.7117
# Traffic Distribution: Pareto
# Simulation time: 106.1 s - Training time: 2.8 s - Total: 108.9 s
# Actor loss: -0.1079, Critic loss: 1625900.6250
# Entropy: 25.380512237548828
#
# ----- Episode 411 of 800
# 0 256
# Simulating...
# Total Queue: 20009    Average Reward: -5.550488599348534
# Average Waiting time: 20.0090
# Average Speed: 8.0854
# Average Queue length: 5.5581
# Traffic Distribution: Weibull
# Simulation time: 31.4 s - Training time: 2.8 s - Total: 34.2 s
# Actor loss: 0.0237, Critic loss: 57273.9062
# Entropy: 18.517820358276367
# Simulating...
# Total Queue: 19763    Average Reward: -5.837662337662338
# Average Waiting time: 19.7630
# Average Speed: 10.9114
# Average Queue length: 5.4897
# Traffic Distribution: Poisson
# Simulation time: 29.8 s - Training time: 2.7 s - Total: 32.5 s
# Actor loss: -0.0022, Critic loss: 34176.2383
# Entropy: 20.516407012939453
# Simulating...
# Total Queue: 289542    Average Reward: -82.2200647249191
# Average Waiting time: 289.5420
# Average Speed: 2.2001
# Average Queue length: 80.4283
# Traffic Distribution: Pareto
# Simulation time: 106.4 s - Training time: 2.8 s - Total: 109.2 s
# Actor loss: -0.1064, Critic loss: 1826039.5000
# Entropy: 24.039737701416016
#
# ----- Episode 412 of 800
# 0 256
# Simulating...
# Total Queue: 19670    Average Reward: -5.568627450980392
# Average Waiting time: 19.6700
# Average Speed: 8.7892
# Average Queue length: 5.4639
# Traffic Distribution: Weibull
# Average Queue length: 3.9947
# Traffic Distribution: Weibull
# Simulation time: 28.6 s - Training time: 2.9 s - Total: 31.5 s
# Actor loss: 0.0412, Critic loss: 42181.3242
# Entropy: 19.65032386779785
# Simulating...
# Total Queue: 12617    Average Reward: -3.6324503311258276
# Average Waiting time: 12.6170
# Average Speed: 10.8823
# Average Queue length: 3.5047
# Traffic Distribution: Poisson
# Simulation time: 28.2 s - Training time: 2.8 s - Total: 31.0 s
# Actor loss: 0.2107, Critic loss: 37734.4336
# Entropy: 18.86001205444336
# Simulating...
# Total Queue: 209857    Average Reward: -61.575949367088604
# Average Waiting time: 209.8570
# Average Speed: 5.9139
# Average Queue length: 58.2936
# Traffic Distribution: Pareto
# Simulation time: 91.1 s - Training time: 2.8 s - Total: 93.9 s
# Actor loss: -0.0161, Critic loss: 1267347.0000
# Entropy: 20.99049949645996
#
# ----- Episode 416 of 800
# 0 256
# Simulating...
# Total Queue: 15612    Average Reward: -4.364820846905538
# Average Waiting time: 15.6120
# Average Speed: 9.8736
# Average Queue length: 4.3367
# Traffic Distribution: Weibull
# Simulation time: 29.5 s - Training time: 2.9 s - Total: 32.4 s
# Actor loss: -0.5198, Critic loss: 69502.4844
# Entropy: 18.740684509277344
# Simulating...
# Total Queue: 14550    Average Reward: -4.059016393442623
# Average Waiting time: 14.5500
# Average Speed: 11.0948
# Average Queue length: 4.0417
# Traffic Distribution: Poisson
# Simulation time: 29.3 s - Training time: 2.7 s - Total: 32.0 s
# Actor loss: -0.1046, Critic loss: 41834.2773
# Entropy: 20.68749237060547
# Simulating...
# Total Queue: 246895    Average Reward: -65.35344827586206
# Average Waiting time: 246.8950
# Average Speed: 3.0865
# Average Queue length: 68.5819
# Traffic Distribution: Pareto
# Simulation time: 103.7 s - Training time: 2.7 s - Total: 106.4 s
# Actor loss: -0.3403, Critic loss: 1453616.3750
# Entropy: 9.601757049560547
#
# ----- Episode 417 of 800
# 0 256
# Simulating...
# Total Queue: 13574    Average Reward: -3.778501628664495
# Average Waiting time: 13.5740
# Average Speed: 10.2738
# Average Queue length: 3.7706
# Traffic Distribution: Weibull
# Simulation time: 29.9 s - Training time: 2.8 s - Total: 32.7 s
# Actor loss: -0.2842, Critic loss: 54177.0469
# Entropy: 18.873437881469727
# Simulating...
# Total Queue: 10798    Average Reward: -3.036184210526316
# Average Waiting time: 10.7980
# Average Speed: 11.5783
# Average Queue length: 2.9994
# Traffic Distribution: Poisson
# Simulation time: 28.9 s - Training time: 2.8 s - Total: 31.7 s
# Actor loss: -0.5644, Critic loss: 20948.2383
# Entropy: 20.265052795410156
# Simulating...
# Total Queue: 231759    Average Reward: -68.4063492063492
# Average Waiting time: 231.7590
# Average Speed: 4.1248
# Average Queue length: 64.3775
# Traffic Distribution: Pareto
# Simulation time: 103.4 s - Training time: 2.7 s - Total: 106.1 s
# Actor loss: -0.0598, Critic loss: 1638289.0000
# Entropy: 21.058685302734375
#
# ----- Episode 418 of 800
# 0 256
# Simulating...
# Total Queue: 13868    Average Reward: -3.9704918032786884
# Entropy: 24.582386016845703
#
# ----- Episode 424 of 800
# 0 256
# Simulating...
# Total Queue: 13267    Average Reward: -3.64
# Average Waiting time: 13.2670
# Average Speed: 10.0469
# Average Queue length: 3.6853
# Traffic Distribution: Weibull
# Simulation time: 28.7 s - Training time: 2.7 s - Total: 31.4 s
# Actor loss: -0.2376, Critic loss: 137269.8438
# Entropy: 19.544235229492188
# Simulating...
# Total Queue: 11741    Average Reward: -3.334437086092715
# Average Waiting time: 11.7410
# Average Speed: 10.9558
# Average Queue length: 3.2614
# Traffic Distribution: Poisson
# Simulation time: 27.8 s - Training time: 2.7 s - Total: 30.5 s
# Actor loss: 0.0787, Critic loss: 48768.6250
# Entropy: 15.22997760772705
# Simulating...
# Total Queue: 251097    Average Reward: -72.00628930817611
# Average Waiting time: 251.0970
# Average Speed: 3.3162
# Average Queue length: 69.7492
# Traffic Distribution: Pareto
# Simulation time: 101.1 s - Training time: 2.7 s - Total: 103.8 s
# Actor loss: -0.3100, Critic loss: 538504.5625
# Entropy: 23.764450073242188
#
# ----- Episode 425 of 800
# 0 256
# Simulating...
# Total Queue: 13930    Average Reward: -4.031847133757962
# Average Waiting time: 13.9300
# Average Speed: 10.0238
# Average Queue length: 3.8694
# Traffic Distribution: Weibull
# Simulation time: 29.5 s - Training time: 2.7 s - Total: 32.2 s
# Actor loss: -0.1675, Critic loss: 89716.4609
# Entropy: 17.99786376953125
# Simulating...
# Total Queue: 20069    Average Reward: -5.5576923076923075
# Average Waiting time: 20.0690
# Average Speed: 9.6682
# Average Queue length: 5.5747
# Traffic Distribution: Poisson
# Simulation time: 30.9 s - Training time: 2.7 s - Total: 33.6 s
# Actor loss: 0.1338, Critic loss: 36401.3984
# Entropy: 19.942371368408203
# Simulating...
# Total Queue: 211611    Average Reward: -64.0059880239521
# Average Waiting time: 211.6110
# Average Speed: 3.5757
# Average Queue length: 58.7808
# Traffic Distribution: Pareto
# Simulation time: 91.4 s - Training time: 2.7 s - Total: 94.1 s
# Actor loss: -0.1923, Critic loss: 902851.5000
# Entropy: 19.798370361328125
#
# ----- Episode 426 of 800
# 0 256
# Simulating...
# Total Queue: 18329    Average Reward: -5.092409240924092
# Average Waiting time: 18.3290
# Average Speed: 9.7075
# Average Queue length: 5.0914
# Traffic Distribution: Weibull
# Simulation time: 31.1 s - Training time: 2.6 s - Total: 33.7 s
# Actor loss: -0.0805, Critic loss: 97191.3047
# Entropy: 19.957611083984375
# Simulating...
# Total Queue: 12705    Average Reward: -3.6295081967213116
# Average Waiting time: 12.7050
# Average Speed: 10.8060
# Average Queue length: 3.5292
# Traffic Distribution: Poisson
# Simulation time: 28.7 s - Training time: 2.6 s - Total: 31.3 s
# Actor loss: -0.0284, Critic loss: 20847.1074
# Entropy: 16.256824493408203
# Simulating...
# Total Queue: 193275    Average Reward: -57.40822784810127
# Average Waiting time: 193.2750
# Average Speed: 5.6273
# Average Queue length: 53.6875
# Traffic Distribution: Pareto
# Simulation time: 84.5 s - Training time: 2.7 s - Total: 87.2 s
# Actor loss: 0.0708, Critic loss: 711514.8125
# Entropy: 22.83165168762207
#
# ----- Episode 427 of 800
# 0 256
# Simulating...
# Total Queue: 16153    Average Reward: -4.561290322580645
# Average Waiting time: 16.1530
# Average Speed: 10.0325
# Average Queue length: 4.4869
# Traffic Distribution: Weibull
# Simulation time: 29.6 s - Training time: 2.8 s - Total: 32.4 s
# Actor loss: -0.0430, Critic loss: 56469.9375
# Entropy: 18.34406852722168
# Simulating...
# Total Queue: 14714    Average Reward: -4.395498392282958
# Average Waiting time: 14.7140
# Average Speed: 10.8522
# Average Queue length: 4.0872
# Traffic Distribution: Poisson
# Simulation time: 30.0 s - Training time: 2.8 s - Total: 32.8 s
# Actor loss: 0.3356, Critic loss: 38324.0078
# Entropy: 18.008296966552734
# Simulating...
# Total Queue: 243478    Average Reward: -71.37898089171975
# Average Waiting time: 243.4780
# Average Speed: 2.8424
# Average Queue length: 67.6328
# Traffic Distribution: Pareto
# Simulation time: 97.6 s - Training time: 2.7 s - Total: 100.3 s
# Actor loss: -0.2829, Critic loss: 7922.2349
# Entropy: 24.822368621826172
#
# ----- Episode 428 of 800
# 0 256
# Simulating...
# Total Queue: 15425    Average Reward: -4.221476510067114
# Average Waiting time: 15.4250
# Average Speed: 10.0814
# Average Queue length: 4.2847
# Traffic Distribution: Weibull
# Simulation time: 28.4 s - Training time: 2.7 s - Total: 31.1 s
# Actor loss: 0.0403, Critic loss: 59255.5781
# Entropy: 16.726511001586914
# Simulating...
# Total Queue: 16737    Average Reward: -4.832236842105263
# Average Waiting time: 16.7370
# Average Speed: 11.1867
# Average Queue length: 4.6492
# Traffic Distribution: Poisson
# Simulation time: 29.5 s - Training time: 2.7 s - Total: 32.2 s
# Actor loss: -0.0920, Critic loss: 29761.5469
# Entropy: 21.65882110595703
# Simulating...
# Total Queue: 225378    Average Reward: -66.35866261398176
# Average Waiting time: 225.3780
# Average Speed: 2.4331
# Average Queue length: 62.6050
# Traffic Distribution: Pareto
# Simulation time: 95.8 s - Training time: 2.6 s - Total: 98.4 s
# Actor loss: 0.0400, Critic loss: 1200643.3750
# Entropy: 18.035537719726562
#
# ----- Episode 429 of 800
# 0 256
# Simulating...
# Total Queue: 14242    Average Reward: -4.043189368770764
# Average Waiting time: 14.2420
# Average Speed: 9.7087
# Average Queue length: 3.9561
# Traffic Distribution: Weibull
# Simulation time: 28.5 s - Training time: 2.7 s - Total: 31.2 s
# Actor loss: -0.5852, Critic loss: 53000.4531
# Entropy: 19.449081420898438
# Simulating...
# Total Queue: 12690    Average Reward: -3.488372093023256
# Average Waiting time: 12.6900
# Average Speed: 11.2940
# Average Queue length: 3.5250
# Traffic Distribution: Poisson
# Simulation time: 27.3 s - Training time: 3.0 s - Total: 30.3 s
# Actor loss: -0.2355, Critic loss: 20212.5195
# Entropy: 18.750534057617188
# Simulating...
# Total Queue: 233032    Average Reward: -66.50613496932516
# Average Waiting time: 233.0320
# Average Speed: 4.0354
# Average Queue length: 64.7311
# Traffic Distribution: Pareto
# Simulation time: 96.0 s - Training time: 2.8 s - Total: 98.8 s
# Actor loss: 0.0208, Critic loss: 227349.8594
# Entropy: 23.227813720703125
#
# ----- Episode 430 of 800
# 0 256
# Simulating...
# Total Queue: 20413    Average Reward: -6.003225806451613
# Average Waiting time: 20.4130
# Average Speed: 10.0798
# Average Queue length: 5.6703
# Traffic Distribution: Weibull
# Simulation time: 31.6 s - Training time: 2.8 s - Total: 34.4 s
# Actor loss: -0.1600, Critic loss: 76060.1406
# Entropy: 23.55035400390625
# Simulating...
# Total Queue: 14315    Average Reward: -4.069078947368421
# Average Waiting time: 14.3150
# Average Speed: 10.1307
# Average Queue length: 3.9764
# Traffic Distribution: Poisson
# Simulation time: 30.8 s - Training time: 2.6 s - Total: 33.4 s
# Actor loss: -0.3488, Critic loss: 25485.9688
# Entropy: 14.10457992553711
# Simulating...
# Total Queue: 216984    Average Reward: -62.95268138801262
# Average Waiting time: 216.9840
# Average Speed: 6.1051
# Average Queue length: 60.2733
# Traffic Distribution: Pareto
# Simulation time: 93.3 s - Training time: 2.7 s - Total: 96.0 s
# Actor loss: -0.0660, Critic loss: 329617.3438
# Entropy: 25.207664489746094
#
# ----- Episode 431 of 800
# 0 256
# Simulating...
# Total Queue: 32803    Average Reward: -9.074534161490684
# Average Waiting time: 32.8030
# Average Speed: 7.3006
# Average Queue length: 9.1119
# Traffic Distribution: Weibull
# Simulation time: 35.2 s - Training time: 2.7 s - Total: 37.9 s
# Actor loss: -0.3337, Critic loss: 90523.9922
# Entropy: 21.780357360839844
# Simulating...
# Total Queue: 16645    Average Reward: -4.651315789473684
# Average Waiting time: 16.6450
# Average Speed: 11.0759
# Average Queue length: 4.6236
# Traffic Distribution: Poisson
# Simulation time: 30.2 s - Training time: 2.8 s - Total: 33.0 s
# Actor loss: 0.0693, Critic loss: 47535.3438
# Entropy: 20.589162826538086
# Simulating...
# Total Queue: 332710    Average Reward: -90.05900621118012
# Average Waiting time: 332.7100
# Average Speed: 1.7020
# Average Queue length: 92.4194
# Traffic Distribution: Pareto
# Simulation time: 124.7 s - Training time: 2.7 s - Total: 127.4 s
# Actor loss: -0.3165, Critic loss: 1290651.7500
# Entropy: 22.961551666259766
#
# ----- Episode 432 of 800
# 0 256
# Simulating...
# Total Queue: 12840    Average Reward: -3.5141955835962144
# Average Waiting time: 12.8400
# Average Speed: 10.3343
# Average Queue length: 3.5667
# Traffic Distribution: Weibull
# Simulation time: 30.8 s - Training time: 2.8 s - Total: 33.6 s
# Actor loss: 0.2549, Critic loss: 81557.0391
# Entropy: 20.76354217529297
# Simulating...
# Total Queue: 15931    Average Reward: -4.5130718954248366
# Average Waiting time: 15.9310
# Average Speed: 10.5366
# Average Queue length: 4.4253
# Traffic Distribution: Poisson
# Simulation time: 30.5 s - Training time: 2.9 s - Total: 33.4 s
# Actor loss: 0.2097, Critic loss: 18300.2285
# Entropy: 20.946372985839844
# Simulating...
# Total Queue: 244089    Average Reward: -64.35989010989012
# Average Waiting time: 244.0890
# Average Speed: 2.4200
# Average Queue length: 67.8025
# Average Speed: 5.3553
# Average Queue length: 64.2514
# Traffic Distribution: Pareto
# Simulation time: 97.2 s - Training time: 2.8 s - Total: 100.0 s
# Actor loss: -0.2779, Critic loss: 213408.6562
# Entropy: 27.007123947143555
#
# ----- Episode 436 of 800
# 0 256
# Simulating...
# Total Queue: 19914    Average Reward: -5.718354430379747
# Average Waiting time: 19.9140
# Average Speed: 9.7032
# Average Queue length: 5.5317
# Traffic Distribution: Weibull
# Simulation time: 32.2 s - Training time: 2.8 s - Total: 35.0 s
# Actor loss: -0.3169, Critic loss: 19457.6309
# Entropy: 19.81891441345215
# Simulating...
# Total Queue: 13255    Average Reward: -3.8524590163934427
# Average Waiting time: 13.2550
# Average Speed: 11.3246
# Average Queue length: 3.6819
# Traffic Distribution: Poisson
# Simulation time: 29.6 s - Training time: 2.8 s - Total: 32.4 s
# Actor loss: 0.0906, Critic loss: 21287.6484
# Entropy: 18.601810455322266
# Simulating...
# Total Queue: 233418    Average Reward: -67.62666666666667
# Average Waiting time: 233.4180
# Average Speed: 4.7375
# Average Queue length: 64.8383
# Traffic Distribution: Pareto
# Simulation time: 96.0 s - Training time: 2.7 s - Total: 98.7 s
# Actor loss: -0.0899, Critic loss: 131182.7500
# Entropy: 25.36143684387207
#
# ----- Episode 437 of 800
# 0 256
# Simulating...
# Total Queue: 14050    Average Reward: -3.763157894736842
# Average Waiting time: 14.0500
# Average Speed: 10.2504
# Average Queue length: 3.9028
# Traffic Distribution: Weibull
# Simulation time: 29.0 s - Training time: 2.7 s - Total: 31.7 s
# Actor loss: -0.0456, Critic loss: 38817.5312
# Entropy: 19.971824645996094
# Simulating...
# Total Queue: 13593    Average Reward: -3.8823529411764706
# Average Waiting time: 13.5930
# Average Speed: 10.5389
# Average Queue length: 3.7758
# Traffic Distribution: Poisson
# Simulation time: 28.5 s - Training time: 2.7 s - Total: 31.2 s
# Actor loss: 0.1090, Critic loss: 38197.7344
# Entropy: 17.393306732177734
# Simulating...
# Total Queue: 238517    Average Reward: -69.96116504854369
# Average Waiting time: 238.5170
# Average Speed: 4.2157
# Average Queue length: 66.2547
# Traffic Distribution: Pareto
# Simulation time: 100.6 s - Training time: 2.7 s - Total: 103.3 s
# Actor loss: -0.1893, Critic loss: 21385.2031
# Entropy: 26.114898681640625
#
# ----- Episode 438 of 800
# 0 256
# Simulating...
# Total Queue: 13548    Average Reward: -3.820261437908497
# Average Waiting time: 13.5480
# Average Speed: 9.2451
# Average Queue length: 3.7633
# Traffic Distribution: Weibull
# Simulation time: 28.9 s - Training time: 2.8 s - Total: 31.7 s
# Actor loss: -0.6288, Critic loss: 42733.2383
# Entropy: 21.956615447998047
# Simulating...
# Total Queue: 14490    Average Reward: -4.120521172638436
# Average Waiting time: 14.4900
# Average Speed: 9.8426
# Average Queue length: 4.0250
# Traffic Distribution: Poisson
# Simulation time: 29.7 s - Training time: 2.7 s - Total: 32.4 s
# Actor loss: 0.1155, Critic loss: 29995.4668
# Entropy: 18.42093849182129
# Simulating...
# Total Queue: 192247    Average Reward: -54.29608938547486
# Simulating...
# Total Queue: 230917    Average Reward: -68.70607028753993
# Average Waiting time: 230.9170
# Average Speed: 3.3962
# Average Queue length: 64.1436
# Traffic Distribution: Pareto
# Simulation time: 97.1 s - Training time: 2.7 s - Total: 99.8 s
# Actor loss: -0.1028, Critic loss: 575309.8750
# Entropy: 23.665895462036133
#
# ----- Episode 442 of 800
# 0 256
# Simulating...
# Total Queue: 21519    Average Reward: -6.02258064516129
# Average Waiting time: 21.5190
# Average Speed: 7.4857
# Average Queue length: 5.9775
# Traffic Distribution: Weibull
# Simulation time: 31.6 s - Training time: 2.8 s - Total: 34.4 s
# Actor loss: -0.0860, Critic loss: 37815.9023
# Entropy: 21.604259490966797
# Simulating...
# Total Queue: 25902    Average Reward: -8.047619047619047
# Average Waiting time: 25.9020
# Average Speed: 10.4199
# Average Queue length: 7.1950
# Traffic Distribution: Poisson
# Simulation time: 34.5 s - Training time: 2.8 s - Total: 37.3 s
# Actor loss: 0.1461, Critic loss: 21807.4746
# Entropy: 15.162304878234863
# Simulating...
# Total Queue: 294603    Average Reward: -82.43492063492063
# Average Waiting time: 294.6030
# Average Speed: 2.4667
# Average Queue length: 81.8342
# Traffic Distribution: Pareto
# Simulation time: 114.0 s - Training time: 2.8 s - Total: 116.8 s
# Actor loss: -0.4186, Critic loss: 35541.1523
# Entropy: 23.4649658203125
#
# ----- Episode 443 of 800
# 0 256
# Simulating...
# Total Queue: 15533    Average Reward: -4.512738853503185
# Average Waiting time: 15.5330
# Average Speed: 9.2782
# Average Queue length: 4.3147
# Traffic Distribution: Weibull
# Simulation time: 30.0 s - Training time: 2.7 s - Total: 32.7 s
# Actor loss: 0.3672, Critic loss: 68786.6641
# Entropy: 17.426769256591797
# Simulating...
# Total Queue: 13790    Average Reward: -4.0344827586206895
# Average Waiting time: 13.7900
# Average Speed: 10.5329
# Average Queue length: 3.8306
# Traffic Distribution: Poisson
# Simulation time: 29.4 s - Training time: 2.9 s - Total: 32.3 s
# Actor loss: 0.1858, Critic loss: 15383.3643
# Entropy: 17.3564395904541
# Simulating...
# Total Queue: 168313    Average Reward: -49.09385113268608
# Average Waiting time: 168.3130
# Average Speed: 7.3576
# Average Queue length: 46.7536
# Traffic Distribution: Pareto
# Simulation time: 84.1 s - Training time: 3.0 s - Total: 87.1 s
# Actor loss: 0.3310, Critic loss: 96599.0859
# Entropy: 22.714168548583984
#
# ----- Episode 444 of 800
# 0 256
# Simulating...
# Total Queue: 29641    Average Reward: -8.254838709677419
# Average Waiting time: 29.6410
# Average Speed: 7.5326
# Average Queue length: 8.2336
# Traffic Distribution: Weibull
# Simulation time: 35.8 s - Training time: 2.8 s - Total: 38.6 s
# Actor loss: -0.7760, Critic loss: 29131.8945
# Entropy: 16.544090270996094
# Simulating...
# Total Queue: 18330    Average Reward: -5.5094936708860756
# Average Waiting time: 18.3300
# Average Speed: 9.4880
# Average Queue length: 5.0917
# Traffic Distribution: Poisson
# Simulation time: 34.2 s - Training time: 2.8 s - Total: 37.0 s
# Actor loss: -0.9370, Critic loss: 59122.2031
# Entropy: 15.648310661315918
# Simulating...
# Total Queue: 317833    Average Reward: -88.72990353697749
# Average Waiting time: 317.8330
# Average Speed: 1.7135
# Average Queue length: 88.2869
# Traffic Distribution: Pareto
# Simulation time: 120.2 s - Training time: 3.1 s - Total: 123.3 s
# Actor loss: -0.5323, Critic loss: 6741.5059
# Entropy: 24.920269012451172
#
# ----- Episode 445 of 800
# 0 256
# Simulating...
# Total Queue: 13547    Average Reward: -3.767213114754098
# Average Waiting time: 13.5470
# Average Speed: 10.5131
# Average Queue length: 3.7631
# Traffic Distribution: Weibull
# Simulation time: 32.5 s - Training time: 2.8 s - Total: 35.3 s
# Actor loss: 0.1300, Critic loss: 56478.4961
# Entropy: 20.797075271606445
# Simulating...
# Total Queue: 14320    Average Reward: -4.216129032258064
# Average Waiting time: 14.3200
# Average Speed: 10.4358
# Average Queue length: 3.9778
# Traffic Distribution: Poisson
# Simulation time: 30.5 s - Training time: 2.7 s - Total: 33.2 s
# Actor loss: -0.0956, Critic loss: 30176.6953
# Entropy: 15.604389190673828
# Simulating...
# Total Queue: 225532    Average Reward: -60.265415549597854
# Average Waiting time: 225.5320
# Average Speed: 2.3340
# Average Queue length: 62.6478
# Traffic Distribution: Pareto
# Simulation time: 103.1 s - Training time: 2.7 s - Total: 105.8 s
# Actor loss: 0.0757, Critic loss: 466426.4688
# Entropy: 7.233922004699707
#
# ----- Episode 446 of 800
# 0 256
# Simulating...
# Total Queue: 19886    Average Reward: -5.507987220447284
# Average Waiting time: 19.8860
# Average Speed: 9.8004
# Average Queue length: 5.5239
# Traffic Distribution: Weibull
# Simulation time: 32.1 s - Training time: 2.8 s - Total: 34.9 s
# Actor loss: -0.1456, Critic loss: 35335.1836
# Entropy: 13.897953033447266
# Simulating...
# Total Queue: 16270    Average Reward: -4.6381578947368425
# Average Waiting time: 16.2700
# Average Speed: 10.6674
# Average Queue length: 4.5194
# Traffic Distribution: Poisson
# Simulation time: 30.5 s - Training time: 2.8 s - Total: 33.3 s
# Actor loss: -0.2537, Critic loss: 20384.5664
# Entropy: 18.62689971923828
# Simulating...
# Total Queue: 252726    Average Reward: -74.36893203883496
# Average Waiting time: 252.7260
# Average Speed: 2.6253
# Average Queue length: 70.2017
# Traffic Distribution: Pareto
# Simulation time: 103.2 s - Training time: 2.6 s - Total: 105.8 s
# Actor loss: -0.1892, Critic loss: 8757.2842
# Entropy: 25.630706787109375
#
# ----- Episode 447 of 800
# 0 256
# Simulating...
# Total Queue: 12431    Average Reward: -3.6310679611650487
# Average Waiting time: 12.4310
# Average Speed: 10.4005
# Average Queue length: 3.4531
# Traffic Distribution: Weibull
# Simulation time: 28.9 s - Training time: 2.7 s - Total: 31.6 s
# Actor loss: -0.1577, Critic loss: 52582.1914
# Entropy: 16.81833267211914
# Simulating...
# Total Queue: 16351    Average Reward: -4.729813664596273
# Average Waiting time: 16.3510
# Average Speed: 11.1095
# Average Queue length: 4.5419
# Traffic Distribution: Poisson
# Simulation time: 30.3 s - Training time: 2.8 s - Total: 33.1 s
# Actor loss: -0.0175, Critic loss: 11655.0879
# Entropy: 14.153987884521484
# Simulating...
# Total Queue: 212262    Average Reward: -61.848101265822784
# Average Waiting time: 212.2620
# Average Speed: 5.2947
# Average Queue length: 58.9617
# Traffic Distribution: Pareto
# Simulation time: 91.2 s - Training time: 2.8 s - Total: 94.0 s
# Actor loss: 0.2200, Critic loss: 214757.5625
# Entropy: 22.137962341308594
#
# ----- Episode 448 of 800
# 0 256
# Simulating...
# Total Queue: 26963    Average Reward: -8.248538011695906
# Average Waiting time: 26.9630
# Average Speed: 7.9777
# Average Queue length: 7.4897
# Traffic Distribution: Weibull
# Simulation time: 32.8 s - Training time: 2.8 s - Total: 35.6 s
# Actor loss: 0.3730, Critic loss: 18443.0195
# Entropy: 11.137441635131836
# Simulating...
# Total Queue: 12722    Average Reward: -3.792332268370607
# Average Waiting time: 12.7220
# Average Speed: 11.2742
# Average Queue length: 3.5339
# Traffic Distribution: Poisson
# Simulation time: 28.6 s - Training time: 2.8 s - Total: 31.4 s
# Actor loss: -0.0589, Critic loss: 9255.3086
# Entropy: 12.37282943725586
# Simulating...
# Total Queue: 184332    Average Reward: -53.41616766467066
# Average Waiting time: 184.3320
# Average Speed: 2.5859
# Average Queue length: 51.2033
# Traffic Distribution: Pareto
# Simulation time: 86.6 s - Training time: 2.9 s - Total: 89.5 s
# Actor loss: 0.3058, Critic loss: 232181.2969
# Entropy: 19.101560592651367
#
# ----- Episode 449 of 800
# 0 256
# Simulating...
# Total Queue: 14437    Average Reward: -4.17981072555205
# Average Waiting time: 14.4370
# Average Speed: 9.8459
# Average Queue length: 4.0103
# Traffic Distribution: Weibull
# Simulation time: 29.7 s - Training time: 2.7 s - Total: 32.4 s
# Actor loss: -0.0886, Critic loss: 12220.6631
# Entropy: 16.893230438232422
# Simulating...
# Total Queue: 13481    Average Reward: -3.7373417721518987
# Average Waiting time: 13.4810
# Average Speed: 11.3577
# Average Queue length: 3.7447
# Traffic Distribution: Poisson
# Simulation time: 29.4 s - Training time: 2.8 s - Total: 32.2 s
# Actor loss: 0.3476, Critic loss: 26653.8906
# Entropy: 14.1766357421875
# Simulating...
# Total Queue: 209507    Average Reward: -59.403125
# Average Waiting time: 209.5070
# Average Speed: 5.2130
# Average Queue length: 58.1964
# Traffic Distribution: Pareto
# Simulation time: 95.0 s - Training time: 2.7 s - Total: 97.7 s
# Actor loss: 0.0070, Critic loss: 15736.0908
# Entropy: 21.484817504882812
#
# ----- Episode 450 of 800
# 0 256
# Simulating...
# Total Queue: 16750    Average Reward: -5.0
# Average Waiting time: 16.7500
# Average Speed: 10.7247
# Average Queue length: 4.6528
# Traffic Distribution: Weibull
# Simulation time: 30.6 s - Training time: 2.7 s - Total: 33.3 s
# Actor loss: 0.2203, Critic loss: 44514.1445
# Entropy: 17.036584854125977
# Simulating...
# Total Queue: 20552    Average Reward: -6.325301204819277
# Average Waiting time: 20.5520
# Average Speed: 10.9723
# Average Queue length: 5.7089
# Traffic Distribution: Poisson
# ...
# Average Queue length: 67.0925
# Traffic Distribution: Pareto
# Simulation time: 99.6 s - Training time: 2.8 s - Total: 102.4 s
# Actor loss: 0.4032, Critic loss: 3354.5344
# Entropy: 12.133686065673828
#
# ----- Episode 785 of 800
# 0 256
# Simulating...
# Total Queue: 14866    Average Reward: -3.7363344051446945
# Average Waiting time: 14.8660
# Average Speed: 10.0674
# Average Queue length: 4.1294
# Traffic Distribution: Weibull
# Simulation time: 31.9 s - Training time: 2.7 s - Total: 34.6 s
# Actor loss: 0.0488, Critic loss: 5799.5049
# Entropy: 12.431550979614258
# Simulating...
# Total Queue: 12581    Average Reward: -3.3409836065573773
# Average Waiting time: 12.5810
# Average Speed: 11.2584
# Average Queue length: 3.4947
# Traffic Distribution: Poisson
# Simulation time: 29.4 s - Training time: 2.7 s - Total: 32.1 s
# Actor loss: -0.1774, Critic loss: 14125.5264
# Entropy: 11.304786682128906
# Simulating...
# Total Queue: 221163    Average Reward: -61.85139318885449
# Average Waiting time: 221.1630
# Average Speed: 5.2361
# Average Queue length: 61.4342
# Traffic Distribution: Pareto
# Simulation time: 100.2 s - Training time: 2.8 s - Total: 103.0 s
# Actor loss: 0.1520, Critic loss: 33594.5195
# Entropy: 19.679243087768555
#
# ----- Episode 786 of 800
# 0 256
# Simulating...
# Total Queue: 16619    Average Reward: -4.496732026143791
# Average Waiting time: 16.6190
# Average Speed: 10.1389
# Average Queue length: 4.6164
# Traffic Distribution: Weibull
# Simulation time: 29.1 s - Training time: 2.8 s - Total: 31.9 s
# Actor loss: -0.4695, Critic loss: 19050.7559
# Entropy: 12.46962833404541
# Simulating...
# Total Queue: 17581    Average Reward: -4.7006578947368425
# Average Waiting time: 17.5810
# Average Speed: 11.0643
# Average Queue length: 4.8836
# Traffic Distribution: Poisson
# Simulation time: 28.9 s - Training time: 2.8 s - Total: 31.7 s
# Actor loss: -0.2365, Critic loss: 4822.5342
# Entropy: 16.988327026367188
# Simulating...
# Total Queue: 235397    Average Reward: -51.97587719298246
# Average Waiting time: 235.3970
# Average Speed: 2.3398
# Average Queue length: 65.3881
# Traffic Distribution: Pareto
# Simulation time: 101.4 s - Training time: 2.7 s - Total: 104.1 s
# Actor loss: -0.2708, Critic loss: 8453.0303
# Entropy: 8.478216171264648
#
# ----- Episode 787 of 800
# 0 256
# Simulating...
# Total Queue: 13549    Average Reward: -3.617940199335548
# Average Waiting time: 13.5490
# Average Speed: 10.3037
# Average Queue length: 3.7636
# Traffic Distribution: Weibull
# Simulation time: 28.2 s - Training time: 2.8 s - Total: 31.0 s
# Actor loss: -0.2622, Critic loss: 7467.9868
# Entropy: 14.781778335571289
# Simulating...
# Total Queue: 15036    Average Reward: -4.3173076923076925
# Average Waiting time: 15.0360
# Average Speed: 10.9677
# Average Queue length: 4.1767
# Traffic Distribution: Poisson
# Simulation time: 29.7 s - Training time: 2.9 s - Total: 32.6 s
# Actor loss: 0.2149, Critic loss: 19410.4668
# Entropy: 15.985879898071289
# Simulating...
# Total Queue: 271251    Average Reward: -75.73417721518987
# Simulating...
# Total Queue: 308286    Average Reward: -63.97149122807018
# Average Waiting time: 308.2860
# Average Speed: 1.4128
# Average Queue length: 85.6350
# Traffic Distribution: Pareto
# Simulation time: 113.2 s - Training time: 2.8 s - Total: 116.0 s
# Actor loss: -0.1379, Critic loss: 3775.8381
# Entropy: 6.39375114440918
#
# ----- Episode 791 of 800
# 0 256
# Simulating...
# Total Queue: 15974    Average Reward: -4.415841584158416
# Average Waiting time: 15.9740
# Average Speed: 9.8684
# Average Queue length: 4.4372
# Traffic Distribution: Weibull
# Simulation time: 28.9 s - Training time: 2.7 s - Total: 31.6 s
# Actor loss: 0.0342, Critic loss: 5002.4570
# Entropy: 11.740220069885254
# Simulating...
# Total Queue: 14723    Average Reward: -3.8932038834951457
# Average Waiting time: 14.7230
# Average Speed: 11.1553
# Average Queue length: 4.0897
# Traffic Distribution: Poisson
# Simulation time: 29.5 s - Training time: 3.2 s - Total: 32.7 s
# Actor loss: -0.3471, Critic loss: 6151.8521
# Entropy: 13.626800537109375
# Simulating...
# Total Queue: 1972607    Average Reward: -567.640625
# Average Waiting time: 1972.6070
# Average Speed: 0.5884
# Average Queue length: 547.9464
# Traffic Distribution: Pareto
# Simulation time: 465.0 s - Training time: 2.9 s - Total: 467.9 s
# Actor loss: -0.0926, Critic loss: 1691434.8750
# Entropy: 10.673583030700684
#
# ----- Episode 792 of 800
# 0 256
# Simulating...
# Total Queue: 16698    Average Reward: -4.522292993630574
# Average Waiting time: 16.6980
# Average Speed: 10.0239
# Average Queue length: 4.6383
# Traffic Distribution: Weibull
# Simulation time: 29.3 s - Training time: 2.8 s - Total: 32.1 s
# Actor loss: 0.1603, Critic loss: 32549.1348
# Entropy: 20.50290870666504
# Simulating...
# Total Queue: 12496    Average Reward: -3.393548387096774
# Average Waiting time: 12.4960
# Average Speed: 10.6112
# Average Queue length: 3.4711
# Traffic Distribution: Poisson
# Simulation time: 27.3 s - Training time: 2.8 s - Total: 30.1 s
# Actor loss: 0.0345, Critic loss: 10480.7559
# Entropy: 12.418033599853516
# Simulating...
# Total Queue: 207492    Average Reward: -53.89736842105263
# Average Waiting time: 207.4920
# Average Speed: 3.1691
# Average Queue length: 57.6367
# Traffic Distribution: Pareto
# Simulation time: 97.2 s - Training time: 2.8 s - Total: 100.0 s
# Actor loss: 0.3356, Critic loss: 4403.6567
# Entropy: 10.202044486999512
#
# ----- Episode 793 of 800
# 0 256
# Simulating...
# Total Queue: 25649    Average Reward: -7.219354838709678
# Average Waiting time: 25.6490
# Average Speed: 9.3810
# Average Queue length: 7.1247
# Traffic Distribution: Weibull
# Simulation time: 33.2 s - Training time: 2.9 s - Total: 36.1 s
# Actor loss: -0.3186, Critic loss: 27739.3242
# Entropy: 11.269018173217773
# Simulating...
# Total Queue: 16166    Average Reward: -4.592105263157895
# Average Waiting time: 16.1660
# Average Speed: 11.2453
# Average Queue length: 4.4906
# Traffic Distribution: Poisson
# Simulation time: 30.5 s - Training time: 2.9 s - Total: 33.4 s
# Actor loss: -0.0822, Critic loss: 10665.5830
# Entropy: 14.268974304199219
# Simulating...
# Total Queue: 215581    Average Reward: -58.298050139275766
# Average Waiting time: 215.5810
# Average Speed: 3.2173
# Average Queue length: 59.8836
# Traffic Distribution: Pareto
# Simulation time: 94.6 s - Training time: 2.7 s - Total: 97.3 s
# Actor loss: -0.1494, Critic loss: 112649.3203
# Entropy: 13.575919151306152
#
# ----- Episode 794 of 800
# 0 256
# Simulating...
# Total Queue: 16224    Average Reward: -4.414012738853503
# Average Waiting time: 16.2240
# Average Speed: 9.8066
# Average Queue length: 4.5067
# Traffic Distribution: Weibull
# Simulation time: 32.1 s - Training time: 3.0 s - Total: 35.1 s
# Actor loss: 0.1131, Critic loss: 34072.7109
# Entropy: 13.85592269897461
# Simulating...
# Total Queue: 16774    Average Reward: -4.598684210526316
# Average Waiting time: 16.7740
# Average Speed: 11.1534
# Average Queue length: 4.6594
# Traffic Distribution: Poisson
# Simulation time: 31.2 s - Training time: 2.6 s - Total: 33.8 s
# Actor loss: -0.3469, Critic loss: 27321.1543
# Entropy: 17.81523895263672
# Simulating...
# Total Queue: 274559    Average Reward: -61.72831050228311
# Average Waiting time: 274.5590
# Average Speed: 2.1572
# Average Queue length: 76.2664
# Traffic Distribution: Pareto
# Simulation time: 114.0 s - Training time: 2.7 s - Total: 116.7 s
# Actor loss: 0.2196, Critic loss: 64870.5312
# Entropy: 6.5172271728515625
#
# ----- Episode 795 of 800
# 0 256
# Simulating...
# Total Queue: 21725    Average Reward: -5.913461538461538
# Average Waiting time: 21.7250
# Average Speed: 9.5741
# Average Queue length: 6.0347
# Traffic Distribution: Weibull
# Simulation time: 30.5 s - Training time: 2.9 s - Total: 33.4 s
# Actor loss: -0.2171, Critic loss: 45673.5781
# Entropy: 12.474432945251465
# Simulating...
# Total Queue: 22786    Average Reward: -6.573248407643312
# Average Waiting time: 22.7860
# Average Speed: 9.5505
# Average Queue length: 6.3294
# Traffic Distribution: Poisson
# Simulation time: 30.9 s - Training time: 2.7 s - Total: 33.6 s
# Actor loss: -0.4293, Critic loss: 20928.2422
# Entropy: 14.968202590942383
# Simulating...
# Total Queue: 212804    Average Reward: -58.83483483483484
# Average Waiting time: 212.8040
# Average Speed: 3.7428
# Average Queue length: 59.1122
# Traffic Distribution: Pareto
# Simulation time: 94.6 s - Training time: 2.7 s - Total: 97.3 s
# Actor loss: -0.0107, Critic loss: 16147.0488
# Entropy: 15.612272262573242
#
# ----- Episode 796 of 800
# 0 256
# Simulating...
# Total Queue: 18694    Average Reward: -4.794871794871795
# Average Waiting time: 18.6940
# Average Speed: 9.4842
# Average Queue length: 5.1928
# Traffic Distribution: Weibull
# Simulation time: 31.0 s - Training time: 2.8 s - Total: 33.8 s
# Actor loss: -0.0236, Critic loss: 30806.8906
# Entropy: 12.235282897949219
# Simulating...
# Total Queue: 17236    Average Reward: -4.582802547770701
# Average Waiting time: 17.2360
# Average Speed: 11.0662
# Average Queue length: 4.7878
# Traffic Distribution: Poisson
# Simulation time: 30.9 s - Training time: 2.7 s - Total: 33.6 s
# Actor loss: 0.1225, Critic loss: 19536.5859
# Entropy: 16.69527244567871
# Simulating...
# Total Queue: 169729    Average Reward: -49.0948275862069
# Average Waiting time: 169.7290
# Average Speed: 5.0883
# Average Queue length: 47.1469
# Traffic Distribution: Pareto
# Simulation time: 84.2 s - Training time: 2.8 s - Total: 87.0 s
# Actor loss: -0.0377, Critic loss: 13746.8613
# Entropy: 15.28222370147705
#
# ----- Episode 797 of 800
# 0 256
# Simulating...
# Total Queue: 17228    Average Reward: -4.4937888198757765
# Average Waiting time: 17.2280
# Average Speed: 9.8089
# Average Queue length: 4.7856
# Traffic Distribution: Weibull
# Simulation time: 29.7 s - Training time: 2.9 s - Total: 32.6 s
# Actor loss: 0.1398, Critic loss: 13683.4629
# Entropy: 11.007608413696289
# Simulating...
# Total Queue: 18240    Average Reward: -4.981072555205047
# Average Waiting time: 18.2400
# Average Speed: 10.9628
# Average Queue length: 5.0667
# Traffic Distribution: Poisson
# Simulation time: 29.9 s - Training time: 2.7 s - Total: 32.6 s
# Actor loss: -0.0209, Critic loss: 22605.6875
# Entropy: 10.945253372192383
# Simulating...
# Total Queue: 189155    Average Reward: -54.204268292682926
# Average Waiting time: 189.1550
# Average Speed: 5.9730
# Average Queue length: 52.5431
# Traffic Distribution: Pareto
# Simulation time: 84.2 s - Training time: 2.7 s - Total: 86.9 s
# Actor loss: -0.0156, Critic loss: 4574.7920
# Entropy: 16.26789665222168
#
# ----- Episode 798 of 800
# 0 256
# Simulating...
# Total Queue: 22684    Average Reward: -5.954682779456193
# Average Waiting time: 22.6840
# Average Speed: 7.5780
# Average Queue length: 6.3011
# Traffic Distribution: Weibull
# Simulation time: 33.1 s - Training time: 2.8 s - Total: 35.9 s
# Actor loss: -0.0247, Critic loss: 6819.7886
# Entropy: 14.021132469177246
# Simulating...
# Total Queue: 16978    Average Reward: -4.565495207667731
# Average Waiting time: 16.9780
# Average Speed: 10.7304
# Average Queue length: 4.7161
# Traffic Distribution: Poisson
# Simulation time: 28.8 s - Training time: 2.7 s - Total: 31.5 s
# Actor loss: 0.4612, Critic loss: 11109.5928
# Entropy: 13.60154914855957
# Simulating...
# Total Queue: 242338    Average Reward: -57.45783132530121
# Average Waiting time: 242.3380
# Average Speed: 1.9892
# Average Queue length: 67.3161
# Traffic Distribution: Pareto
# Simulation time: 107.8 s - Training time: 2.9 s - Total: 110.7 s
# Actor loss: -0.1087, Critic loss: 3774.6289
# Entropy: 3.807094097137451
#
# ----- Episode 799 of 800
# 0 256
# Simulating...
# Total Queue: 20900    Average Reward: -5.5
# Average Waiting time: 20.9000
# Average Speed: 9.6722
# Average Queue length: 5.8056
# Traffic Distribution: Weibull
# Simulation time: 34.1 s - Training time: 2.8 s - Total: 36.9 s
# Actor loss: -0.1296, Critic loss: 16179.4482
# Entropy: 15.315473556518555
# Simulating...
# Total Queue: 19058    Average Reward: -5.4145569620253164
# Average Waiting time: 19.0580
# Average Speed: 10.7956
# Average Queue length: 5.2939
# Traffic Distribution: Poisson
# Simulation time: 32.1 s - Training time: 2.9 s - Total: 35.0 s
# Actor loss: -0.1468, Critic loss: 7101.4414
# Entropy: 17.231754302978516
# Simulating...
# Total Queue: 226453    Average Reward: -64.11111111111111
# Average Waiting time: 226.4530
# Average Speed: 3.4245
# Average Queue length: 62.9036
# Traffic Distribution: Pareto
# Simulation time: 108.4 s - Training time: 2.8 s - Total: 111.2 s
# Actor loss: -0.3136, Critic loss: 2441.8481
# Entropy: 16.816959381103516
#
# ----- Episode 800 of 800
# 0 256
# Simulating...
# Total Queue: 17214    Average Reward: -4.545454545454546
# Average Waiting time: 17.2140
# Average Speed: 9.8256
# Average Queue length: 4.7817
# Traffic Distribution: Weibull
# Simulation time: 32.8 s - Training time: 3.1 s - Total: 35.9 s
# Actor loss: -0.2695, Critic loss: 10772.8662
# Entropy: 14.57492733001709
# Simulating...
# Total Queue: 14154    Average Reward: -3.745819397993311
# Average Waiting time: 14.1540
# Average Speed: 11.2764
# Average Queue length: 3.9317
# Traffic Distribution: Poisson
# Simulation time: 30.0 s - Training time: 2.9 s - Total: 32.9 s
# Actor loss: 0.0508, Critic loss: 4127.1558
# Entropy: 14.592483520507812
# Simulating...
# Total Queue: 239642    Average Reward: -66.19937694704049
# Average Waiting time: 239.6420
# Average Speed: 4.2326
# Average Queue length: 66.5672
# Traffic Distribution: Pareto
# Simulation time: 111.2 s - Training time: 3.0 s - Total: 114.2 s
# Actor loss: 0.0611, Critic loss: 50087.8711
# Entropy: 14.27752685546875

# %%
'''score, eval_time = evaluate_policy(evaluation, agent, turns=5) # evaluate the policy for 3 times, and get averaged result
print('Evaluation time:', eval_time, 's', 'Score:', score)'''
# Out:
# Simulating...
# Total Queue: 149675    Average Reward: -37.20935960591133
# Average Waiting time: 149.6750
# Average Speed: 3.4488
# Average Queue length: 41.5764
# Simulating...
# Total Queue: 121355    Average Reward: -34.2192118226601
# Average Waiting time: 121.3550
# Average Speed: 4.8222
# Average Queue length: 33.7097
# Simulating...
# Total Queue: 133636    Average Reward: -36.42118226600985
# Average Waiting time: 133.6360
# Average Speed: 4.7243
# Average Queue length: 37.1211
# Simulating...
# Total Queue: 121500    Average Reward: -32.243037974683546
# Average Waiting time: 121.5000
# Average Speed: 4.7610
# Average Queue length: 33.7500
# Simulating...
# Total Queue: 102156    Average Reward: -28.031784841075794
# Average Waiting time: 102.1560
# Average Speed: 5.0329
# Average Queue length: 28.3767
# Evaluation time: 278.0 s Score: -33

# %%
episode = '800_3Dists'

torch.save(agent.critic.state_dict(), "./models/ppo_critic{}.pth".format(episode))
torch.save(agent.actor.state_dict(), "./models/ppo_actor{}.pth".format(episode))

# %%
model_to_test = '800_LSTM-CNN'
config = import_train_configuration(config_file='training_settings.ini')
sumo_cmd = set_sumo(True, config['sumocfg_file_name'], 3600)
path = set_train_path(config['models_path_name'])
#model_path = get_model_path(config['models_path_name'], model_to_test)
#print(model_path)

opt = PPOOptions(entropy_coef = 0.1, T_horizon = 256, eval_interval= 500, K_epochs=15, adv_normalization = True, batch_size=16, lr = 2.5e-4, l2_reg=0.2)
opt.dvc = torch.device(opt.dvc) # from str to torch.device
opt.state_dim = [3,48,46]
opt.action_dim = 8
opt.max_e_steps = 7200
n_cars_generated = 2400
green_duration = 7
yellow_duration = 6
total_episodes = 500

agent = PPO_agent(**vars(opt)) #DRL_Model(num_layers, width_layers, batch_size, learning_rate, input_dim=num_states, output_dim=num_actions,tau=1,num_atoms=num_atoms)

agent.load(model_to_test)

trafficGen = TrafficGenerator(opt.max_e_steps, n_cars_generated)

visualization = Visualization(path, dpi=96)
    
sumo_cmd = set_sumo(True, config['sumocfg_file_name'], 3600)
evaluation = Simulation(agent,trafficGen,sumo_cmd,opt.max_e_steps,green_duration,yellow_duration,opt.state_dim,opt.action_dim, True, opt.dvc)
score, eval_time = evaluate_policy(evaluation, agent, turns=2) # evaluate the policy for 3 times, and get averaged result
print('Evaluation time:', eval_time, 's', 'Score:', score)
# Out:
# Simulating...
# Total Queue: 43444    Average Reward: -5.171390013495277
# Average Waiting time: 43.4440
# Average Speed: 10.1502
# Average Queue length: 6.0339
# Simulating...

# %%
visualization.save_data_and_plot(data=simulation.reward_store, filename='reward', xlabel='Episode', ylabel='Cumulative negative reward')  #np.log(-1*np.array((simulation.reward_store)))

# %%
import matplotlib.pyplot as plt
plt.plot(np.hstack((simulation.reward_store[:800][::2],simulation.reward_store[800:][::3])))
plt.plot(np.hstack((simulation.reward_store[:800][1::2],simulation.reward_store[800:][1::3])))

# %%
plt.plot(simulation.reward_store[800:][2::3])

# %%
visualization.save_data_and_plot(data=simulation.cumulative_wait_store, filename='delay', xlabel='Episode', ylabel='Cumulative delay (s)')

# %%
visualization.save_data_and_plot(data=simulation.avg_queue_length_store, filename='queue', xlabel='Episode', ylabel='Average queue length (vehicles)')

# %%
visualization.save_data_and_plot(data=simulation.speed_store, filename='Speed', xlabel='Episode', ylabel='Average Speed')

# %%
visualization.save_data_and_plot(data=[loss.cpu().detach() for loss in agent.actor_losses], filename='Actor_losses', xlabel='Episode', ylabel='Loss')

# %%
visualization.save_data_and_plot(data=[loss.cpu().detach() for loss in agent.critic_losses], filename='Critic_losses', xlabel='Episode', ylabel='Loss')

# %%
visualization.save_data_and_plot(data=[loss.cpu().detach() for loss in agent.entropies], filename='Critic_entropy', xlabel='Episode', ylabel='Entropy')

# %%
visualization.save_data_and_plot(data=evaluation.cumulative_wait_store, filename='wait_eva', xlabel='Episode', ylabel='Cumulative wait times')

# %%
visualization.save_data_and_plot(data=evaluation.reward_store, filename='reward_eva', xlabel='Episode', ylabel='Cumulative negative reward')

# %%
import matplotlib.pyplot as plt
idx = 50
state_img = agent.s_hoder[idx].transpose((1,2,0))

plt.figure(figsize=(12,4))
plt.title('State representation example')
plt.axis('off')
plt.subplot(141)
plt.imshow(state_img[:,:,0])
plt.axis('off')
plt.subplot(142)
plt.imshow(state_img[:,:,1])
plt.axis('off')
plt.subplot(143)
plt.imshow(state_img[:,:,2])
plt.axis('off')
plt.subplot(144)
plt.imshow(state_img)
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
